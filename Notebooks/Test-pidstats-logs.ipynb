# %%
import pandas as pd

# %%
FN = "~/db_data/testr.log"
FN2 = "~/db_data/testh.log"

# %%
pd.read_csv(FN, sep=r"\s+")
# Out:
#      1678167079   UID  PID  minflt/s  majflt/s     VSZ    RSS  %MEM  \
# 0    1678167079     0    1     15.78      0.22  166588  10752  0.07
# 1    1678167079     0    2      0.00      0.00       0      0  0.00
# 2    1678167079     0    3      0.00      0.00       0      0  0.00
# 3    1678167079     0    4      0.00      0.00       0      0  0.00
# 4    1678167079     0    5      0.00      0.00       0      0  0.00
# ..          ...   ...  ...       ...       ...     ...    ...   ...
# 126  1678167079  1000  959      0.53      0.00   18552   6612  0.04
# 127  1678167079  1000  960      2.76      0.01    8608   4860  0.03
# 128  1678167079     0  975      0.00      0.00       0      0  0.00
# 129  1678167079     0  976      0.00      0.00       0      0  0.00
# 130  1678167079  1000  983      0.61      0.00    6660   2708  0.02
#
#                       Command
# 0                     systemd
# 1                    kthreadd
# 2                      rcu_gp
# ...

# %%
pd.read_csv(FN2, sep=r"\s+")
# Out:
#               #  Time  UID   PID  %usr  %system  %guest  %wait  %CPU  \
# 0    1678167098     0    1  0.01  0.15      0.0    0.01   0.16     0
# 1    1678167098     0    2  0.00  0.00      0.0    0.00   0.00     1
# 2    1678167098     0    3  0.00  0.00      0.0    0.00   0.00     0
# 3    1678167098     0    4  0.00  0.00      0.0    0.00   0.00     0
# 4    1678167098     0    5  0.00  0.00      0.0    0.00   0.00     0
# ..          ...   ...  ...   ...   ...      ...     ...    ...   ...
# 126  1678167098  1000  959  0.00  0.00      0.0    0.00   0.00     0
# 127  1678167098  1000  960  0.00  0.00      0.0    0.00   0.00     0
# 128  1678167098     0  975  0.00  0.00      0.0    0.00   0.00     1
# 129  1678167098     0  976  0.00  0.00      0.0    0.00   0.00     0
# 130  1678167098  1000  993  0.00  0.00      0.0    0.00   0.00     1
#
#                           CPU  Command
# 0                     systemd      NaN
# 1                    kthreadd      NaN
# ...
