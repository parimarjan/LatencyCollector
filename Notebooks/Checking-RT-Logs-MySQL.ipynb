# %%
# %load_ext autoreload
# %autoreload 2

from utils import *
import numpy as np
import pandas as pd
import sys
sys.path.append("..")

from torch.utils import data

import glob
import random
import os
import json
import time
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO

from bokeh.io import push_notebook, show, output_notebook,reset_output
from bokeh.plotting import figure
import networkx as nx
from bokeh.plotting import figure, from_networkx, curdoc
from bokeh.models import Rect, HoverTool,  TextInput, GraphRenderer, Circle
from bokeh.io import output_file
from bokeh.plotting import figure, output_file, save
from bokeh.models import (BoxZoomTool, Circle, Line, HoverTool,
                          MultiLine, Plot, Range1d, ResetTool)
from bokeh.models import LinearColorMapper, BasicTicker, ColorBar,CustomJSHover,CustomJS
from bokeh.models import Ellipse, GraphRenderer, StaticLayoutProvider

import grandalf

output_notebook()

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1003">Loading BokehJS ...</span>
#     </div>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
QDIR = os.path.join("/Users/pari/LatencyCollector/queries")
JOB_QNAMES = get_qnames(os.path.join(QDIR, "job"))
CEB_QNAMES = get_qnames(os.path.join(QDIR, "ceb-small"))
ERG_QNAMES = get_qnames(os.path.join(QDIR, "ergast-small"))
STATS_QNAMES = get_qnames(os.path.join(QDIR, "stats"))
JOBLT_QNAMES = get_qnames(os.path.join(QDIR, "joblight_train"))
STACK_QNAMES = get_qnames(os.path.join(QDIR, "stack-small"))
TPCH_QNAMES = get_qnames(os.path.join(QDIR, "tpch"))
ACC_QNAMES = get_qnames(os.path.join(QDIR, "accidents"))

LT_FN = "lt_instances.txt"

#EXP_NAMES = ["exp14_single_stack"]

#EXP_NAMES = ["exp-debug2"]

#EXP_NAMES = ["exp-ceb-likes"]
EXP_NAMES = ["exp-ceb2"]

#EXP_NAMES = ["exp6_multi4b"]

#EXP_NAMES = ["exp1_single", "exp2_single", "exp3_single"]
#EXP_NAMES = ["exp3_single"]


#EXP_NAMES = ["exp1-imdb-n2"]
#EXP_NAMES = ["exp2-imdb-n8"]

#EXP_NAMES = ["exp8_single_stack"]
#EXP_NAMES = ["exp5_single_stats"]
#EXP_NAMES = ["exp6_single_joblight"]
#EXP_NAMES = ["exp7_single_ceb2"]
#EXP_NAMES = ["exp13_imdb"]
#EXP_NAMES = ["exp4_single_ergast"]
#EXP_NAMES = ["exp9_single_tpch"]

#RESULTDIR = os.path.join("/Users/pari/prism-testbed/", "LatencyCollectorResults", "new", EXP_NAME)

LT_TYPES = '''a1_large_mag_4g=lt-0d15fb8f5bbe9a27d
a1_large_gp3_4g=lt-04840b55d3f795395
r7g_large_gp2_16g=lt-0212ec953ba35b176
t3_large_gp2_8g=lt-05d2d354bc3dd9133
c5a_large_mag_4g=lt-03218e9e27718bbbe
m6a_large_mag_8g=lt-0f6f46002652f9a4c
t3a_medium_gp3_4g=lt-0af65294350b1a8c1
t3a_large_gp3_8g=lt-084bfbae110d52d4e
r6a_large_mag_16g=lt-0e608666ff3adff07
t4g_large_mag_8g=lt-04e0b4826c63bfadb
c7g_large_mag_4g=lt-0af47c6caa3b53b8b
r7g_medium_gp2_16g=lt-01d0081183a7d79f2
t3_xlarge_gp2_16g=lt-0b413bcc22b3ac8fb
'''

lt_types = pd.read_csv(StringIO(LT_TYPES), sep="=", header=None, 
                       names=["lt_type", "lt"])
# ltdf = pd.read_csv(os.path.join(RESULTDIR, LT_FN), header=None, 
#                    names=["instance", "lt"])
# ltdf = ltdf.merge(lt_types, on="lt")
# ltdf

# %%
# print(os.path.exists(RESULTDIR))

dfs = []
for exp in EXP_NAMES:
    #resultdir = os.path.join("/Users/pari/prism-testbed/", "LatencyCollectorResults", "concurrent", exp)
    resultdir = os.path.join("/Users/pari/prism-testbed/", "LatencyCollectorResults", "mysql", exp)
    #resultdir = os.path.join("/Users/pari/prism-testbed/", "LatencyCollectorResults", "new", exp)
    print(resultdir)
    assert os.path.exists(resultdir)
    ltdf = pd.read_csv(os.path.join(resultdir, LT_FN), header=None, 
                   names=["instance", "lt"],
                      
                      )
    ltdf = ltdf.merge(lt_types, on="lt")
    
    rtfns = glob.iglob(resultdir + "/*/results/Runtime*.csv")

    for rtfn in rtfns:
        instance_name = os.path.basename(os.path.dirname(os.path.dirname(rtfn)))
        rt = pd.read_csv(rtfn, on_bad_lines="skip")
        rt["instance"] = instance_name
        rt = rt.merge(ltdf, on="instance")
        if len(rt) == 0:
            print(instance_name)
            continue
        mintime = min(rt["start_time"].values)
        rt["relative_start_time"] = rt.apply(lambda x: x["start_time"]-mintime , axis=1)

        dfs.append(rt)
    
df = pd.concat(dfs)
# Out:
# /Users/pari/prism-testbed/LatencyCollectorResults/mysql/exp-ceb2

# %%
print(df["runtime"].sum())
print(df["runtime"].describe())
print(df.keys())
# Out:
# 166187.77363467216
# count    4775.000000
# mean       34.803722
# std        82.600844
# min        -1.000000
# 25%        -1.000000
# 50%        -1.000000
# 75%        24.398783
# max       706.971874
# Name: runtime, dtype: float64
# Index(['start_time', 'qname', 'runtime', 'exp_analyze', 'samples_type',
#        'parallel_workers', 'no_index', 'drop_cache', 'col_store', 'dbms',
#        'result_dir', 'query_dir', 'cost_model', 'materialize', 'explain',
#        'reps', 'num_queries', 'timeout', 'rerun_timeouts', 'db_name',
#        'db_host', 'user', 'pwd', 'port', 'instance', 'lt', 'lt_type',
#        'relative_start_time'],
#       dtype='object')

# %%
#df = df[df["lt_type"] != "a1_large_mag_4g"]
df = df[df["runtime"] > 0.0]
df = df[df["runtime"] < 909.0]
#df = df[~df["qname"].str.contains("credit")]
#df = df[df["qname"].str.contains("walmart")]

# %%
print(len(df.groupby(["lt_type"])["runtime"].describe(percentiles=[0.90, 0.99])))
df.groupby(["lt_type"])["runtime"].describe(percentiles=[0.90, 0.99]).round(2)
# Out:
# 10
#                    count    mean     std  min    50%     90%     99%     max
# lt_type
# a1_large_gp3_4g    205.0  129.12  164.78  0.0  58.66  378.52  699.51  706.97
# c5a_large_mag_4g   210.0   80.14   96.84  0.0  42.95  225.50  413.58  422.46
# c7g_large_mag_4g   210.0  104.64  124.45  0.0  54.41  298.41  496.20  520.50
# m6a_large_mag_8g   210.0   45.01   55.54  0.0  22.07  129.36  205.43  264.19
# r6a_large_mag_16g  210.0   32.26   39.90  0.0  16.22   92.81  158.32  185.83
# r7g_large_gp2_16g  210.0   48.79   60.87  0.0  22.03  142.67  250.63  258.76
# t3_large_gp2_8g    210.0  100.37  123.31  0.0  45.73  281.67  497.25  507.67
# t3_xlarge_gp2_16g  210.0   81.54   99.59  0.0  36.19  225.75  395.34  433.47
# t3a_medium_gp3_4g  210.0   91.23  111.47  0.0  45.44  271.72  452.18  461.70
# t4g_large_mag_8g   210.0   94.10  113.43  0.0  48.58  267.35  455.07  472.03

# %%
len(set(df["qname"]))
# Out:
# 70

# %%
#df = pd.DataFrame(data)

# Group by 'tag', 'lt_type', and 'query', then calculate standard deviation for 'runtime'
std_per_group = df.groupby(['query_dir', 'lt_type', 'qname'])['runtime'].std()

# For each 'tag', calculate the average of these standard deviations
average_std_per_tag = std_per_group.groupby('query_dir').mean()

# Converting the Series to a DataFrame for better table formatting
average_std_table = average_std_per_tag.reset_index()
average_std_table.columns = ['Tag', 'Average_Std']

average_std_table
# Out:
#                     Tag  Average_Std
# 0  ./queries/ceb-small2     3.932428

# %%
len(set(df["qname"]))
# Out:
# 140

# %%
exp_plan_str = df["exp_analyze"].values[0]

# %%
exp_plan_str
# Out:
# '[(\'{\\n  "query_block": {\\n    "select_id": 1,\\n    "cost_info": {\\n      "query_cost": "15883.81"\\n    },\\n    "nested_loop": [\\n      {\\n        "table": {\\n          "table_name": "it1",\\n          "access_type": "const",\\n          "possible_keys": [\\n            "PRIMARY"\\n          ],\\n          "key": "PRIMARY",\\n          "used_key_parts": [\\n            "id"\\n          ],\\n          "key_length": "4",\\n          "ref": [\\n            "const"\\n          ],\\n          "rows_examined_per_scan": 1,\\n          "rows_produced_per_join": 1,\\n          "filtered": "100.00",\\n          "using_index": true,\\n          "cost_info": {\\n            "read_cost": "0.00",\\n            "eval_cost": "0.10",\\n            "prefix_cost": "0.00",\\n            "data_read_per_join": "136"\\n          },\\n          "used_columns": [\\n            "id"\\n          ]\\n        }\\n      },\\n      {\\n        "table": {\\n          "table_name": "it2",\\n          "access_type": "const",\\n          "possible_keys": [\\n            "PRIMARY"\\n          ],\\n          "key": "PRIMARY",\\n          "used_key_parts": [\\n            "id"\\n          ],\\n          "key_length": "4",\\n          "ref": [\\n            "const"\\n          ],\\n          "rows_examined_per_scan": 1,\\n          "rows_produced_per_join": 1,\\n          "filtered": "100.00",\\n          "using_index": true,\\n          "cost_info": {\\n            "read_cost": "0.00",\\n            "eval_cost": "0.10",\\n            "prefix_cost": "0.00",\\n            "data_read_per_join": "136"\\n          },\\n          "used_columns": [\\n            "id"\\n          ]\\n        }\\n      },\\n      {\\n        "table": {\\n          "table_name": "rt",\\n          "access_type": "ALL",\\n          "possible_keys": [\\n            "PRIMARY"\\n          ],\\n          "rows_examined_per_scan": 13,\\n          "rows_produced_per_join": 1,\\n          "filtered": "10.00",\\n          "cost_info": {\\n            "read_cost": "2.17",\\n            "eval_cost": "0.13",\\n            "prefix_cost": "2.30",\\n            "data_read_per_join": "176"\\n          },\\n          "used_columns": [\\n            "id",\\n            "role"\\n          ],\\n          "attached_condition": "(`imdb`.`rt`.`role` = \\\'writer\\\')"\\n        }\\n      },\\n      {\\n        "table": {\\n          "table_name": "ci",\\n          "access_type": "ref",\\n          "possible_keys": [\\n            "ci1",\\n            "ci2",\\n            "ci3"\\n          ],\\n          "key": "ci3",\\n          "used_key_parts": [\\n            "role_id"\\n          ],\\n          "key_length": "4",\\n          "ref": [\\n            "imdb.rt.id"\\n          ],\\n          "rows_examined_per_scan": 4957,\\n          "rows_produced_per_join": 6444,\\n          "filtered": "100.00",\\n          "cost_info": {\\n            "read_cost": "6444.64",\\n            "eval_cost": "644.47",\\n            "prefix_cost": "7091.40",\\n            "data_read_per_join": "251K"\\n          },\\n          "used_columns": [\\n            "person_id",\\n            "movie_id",\\n            "role_id"\\n          ]\\n        }\\n      },\\n      {\\n        "table": {\\n          "table_name": "t",\\n          "access_type": "eq_ref",\\n          "possible_keys": [\\n            "PRIMARY",\\n            "title1"\\n          ],\\n          "key": "PRIMARY",\\n          "used_key_parts": [\\n            "id"\\n          ],\\n          "key_length": "4",\\n          "ref": [\\n            "imdb.ci.movie_id"\\n          ],\\n          "rows_examined_per_scan": 1,\\n          "rows_produced_per_join": 715,\\n          "filtered": "11.11",\\n          "cost_info": {\\n            "read_cost": "6444.46",\\n            "eval_cost": "71.59",\\n            "prefix_cost": "14180.33",\\n            "data_read_per_join": "1M"\\n          },\\n          "used_columns": [\\n            "id",\\n            "kind_id",\\n   ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 61
#      57     return G
#      59 # Example usage:
#      60 # json_blob = '...'  # Your JSON blob here
# ---> 61 graph = create_networkx_graph_from_json(exp_plan_str)
#      62 # Now, 'graph' is a NetworkX graph representing your execution plan.
#
# Cell In[10], line 53, in create_networkx_graph_from_json(json_blob)
#      51 """ Creates a NetworkX graph from a DuckDB execution plan JSON blob. """
#      52 #json_data = json.loads(json_blob)
# ---> 53 json_data = json.loads(eval(json_blob)[0][1])
#      54 json_data = json_data["children"][0]["children"][0]
#      55 G = nx.DiGraph()
#
# IndexError: tuple index out of range

# %%
def convert_to_float(value):
    """
    Converts a string to a float, handling strings ending in K, M, B, etc.
    by converting them to their numerical equivalents.
    """
    if value[-1].isdigit():  # Check if the last character is a digit
        return float(value)
    
    multipliers = {'K': 1e3, 'M': 1e6, 'B': 1e9}
    multiplier = multipliers.get(value[-1].upper(), 1)
    
    return float(value[:-1]) * multiplier

plan = json.loads(eval(exp_plan_str)[0][0])["query_block"]
G = nx.DiGraph()

prev_node = None
for node in plan["nested_loop"]:
    cur_node = node["table"]["table_name"]
    G.add_node(cur_node)
    
    for k,v in node["table"].items():
        if isinstance(v, dict):
            for k2,v2 in v.items():
                G.nodes()[cur_node][k2] = convert_to_float(v2)
        elif isinstance(v, list):
            G.nodes()[cur_node][k] = v
        else:
            G.nodes()[cur_node][k] = v
    
    if prev_node is not None:
        join_node = prev_node + "-" + cur_node
        G.add_node(join_node)
        G.add_edge(prev_node, join_node)
        G.add_edge(cur_node, join_node)
        prev_node = join_node
    else:
        prev_node = cur_node
        
print(G.nodes())
# Out:
# ['it1', 'it2', 'it1-it2', 'rt', 'it1-it2-rt', 'ci', 'it1-it2-rt-ci', 't', 'it1-it2-rt-ci-t', 'n', 'it1-it2-rt-ci-t-n', 'mi2', 'it1-it2-rt-ci-t-n-mi2', 'mi1', 'it1-it2-rt-ci-t-n-mi2-mi1', 'kt', 'it1-it2-rt-ci-t-n-mi2-mi1-kt']

# %%
plan["cost_info"]
# Out:
# {'query_cost': '15883.81'}

# %%
def plot_graph(G):
    tmp = nx.Graph()
    
    for edge in G.edges():
        tmp.add_edge(edge[0], edge[1])
        
    pos = nx.nx_pydot.graphviz_layout(tmp, prog="dot")

    # Draw the graph
    plt.figure(figsize=(12, 16))  # Set the size of the plot
    
    #G = G.reverse()
    nx.draw(G, pos, with_labels=True, arrows=True, node_size=3000, node_color="lightblue", 
            font_size=10, font_weight="bold", edge_color="gray")

    # Show the plot
    plt.show()
    
plot_graph(G)

# %%
exp_plan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 exp_plan
#
# NameError: name 'exp_plan' is not defined

# %%
exp_plan["children"][0]["children"][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 exp_plan["children"][0]["children"][0]
#
# NameError: name 'exp_plan' is not defined

# %%
eval(exp_plan)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 eval(exp_plan)
#
# TypeError: eval() arg 1 must be a string, bytes or code object

# %%
exp_plan["extra-info"]
# Out:
# "explain analyze SELECT n.name, mi1.info, MIN(t.production_year), MAX(t.production_year)\nFROM title as t,\nkind_type as kt,\nmovie_info as mi1,\ninfo_type as it1,\ncast_info as ci,\nrole_type as rt,\nname as n\nWHERE\nt.id = ci.movie_id\nAND t.id = mi1.movie_id\nAND mi1.info_type_id = it1.id\nAND t.kind_id = kt.id\nAND ci.person_id = n.id\nAND ci.movie_id = mi1.movie_id\nAND ci.role_id = rt.id\nAND (it1.id IN ('5','6'))\nAND (mi1.info IN ('Argentina:18','Argentina:Atp','Australia:R','Brazil:14','Germany:16','Ireland:18','Netherlands:12','Netherlands:AL','Philippines:PG-13','South Korea:18','Sweden:7','UK:18','UK:U','USA:Passed'))\nAND (n.name ILIKE '%ung%')\nAND (kt.kind IN ('episode','movie','tv movie'))\nAND (rt.role IN ('actor','cinematographer','composer','costume designer'))\nGROUP BY mi1.info, n.name\n"

# %%
tmp = df[df["runtime"] < 900.0]
tmp.groupby(["lt_type"])["runtime"].describe(percentiles=[0.90, 0.99]).round(2)
# Out:
#                     count  mean   std   min   50%    90%    99%    max
# lt_type
# a1_large_gp3_4g     111.0  6.45  7.17  1.33  3.32  13.20  23.42  57.07
# c5a_large_mag_4g    122.0  5.60  9.03  0.75  2.26  12.05  48.99  58.69
# c7g_large_mag_4g    209.0  3.31  6.71  0.14  1.27   5.80  37.70  53.15
# m6a_large_mag_8g    258.0  2.71  3.89  0.03  1.56   6.22  15.85  45.00
# r6a_large_mag_16g    52.0  3.03  3.47  0.65  1.71   6.62  14.87  23.26
# r7g_large_gp2_16g   374.0  1.84  2.56  0.03  1.07   3.90  10.31  36.02
# r7g_medium_gp2_16g  145.0  4.93  6.65  0.82  3.25   8.42  25.23  69.54
# t3_large_gp2_8g      35.0  6.40  7.96  1.02  3.66  11.52  36.42  45.86
# t3_xlarge_gp2_16g   279.0  2.44  3.34  0.05  1.39   5.48  14.74  40.10
# t3a_medium_gp3_4g    37.0  6.97  9.05  1.06  3.81  12.56  41.49  52.86
# t4g_large_mag_8g    142.0  4.49  6.10  0.66  2.49   9.20  28.11  55.92

# %%
LTTYPES = list(set(df["lt_type"]))
LTTYPES.sort()
LTTYPES
# Out:
# ['a1_large_gp3_4g',
#  'c5a_large_mag_4g',
#  'c7g_large_mag_4g',
#  'm6a_large_mag_8g',
#  'r6a_large_mag_16g',
#  'r7g_large_gp2_16g',
#  't3_large_gp2_8g',
#  't3_xlarge_gp2_16g',
#  't3a_medium_gp3_4g',
#  't4g_large_mag_8g']

# %%
TEST_INSTANCES = ["a1_large_gp3_4g", "c7g_large_mag_4g", "r7g_large_gp2_16g", "t3a_medium_gp3_4g", 
                  "m6a_large_mag_8g", "t4g_large_mag_8g"]

# %%
set(df["qname"])
# Out:
# {'00115a785f16c3cc2a3d8dd01cdaacbc1bad7978.sql',
#  '006ad3e743b877a991463e0149f02e8c349a3c31.sql',
#  '0082f3ed627d38d1dc2d01910f1f5b67cc12b51e.sql',
#  '0701574e1eeb73de1f5e67407c2f63eadc8344aa.sql',
#  '07c0b3b296bac4c12b2363b47fa23fcfcb26fae9.sql',
#  '08eafbdf8f0952a5de815945c7563a0e37aa53c8.sql',
#  '0d9fe153613982c6c003f92736280a83b55782d5.sql',
#  '0f05350b51ae5ac12ec73d03ceaf618376a9bcbf.sql',
#  '11a83131985d2742cb333582ff7317a80fbcb587.sql',
#  '130008519a1efd315d28b98b2fe4e71e5c7190c7.sql',
#  '134ee2c0fbd159b41c07050c2b59b6cc5c3593b1.sql',
#  '162d50b659f6b28462dabb68782720b1b3829a5e.sql',
#  '17206e5e52373d88e5618fa92e5dc3f47d0a2df3.sql',
#  '17b2f0f8db0541f33501acfac7bc210ed023897c.sql',
#  '19cd146e1f13d4ef5e5aeedea48afb20497a844d.sql',
#  '1a7ffe741a24cc8409450955a238fb71b2a3a1d3.sql',
#  '1cad7ba67ded31b9e21a69986d2bd33796875dc6.sql',
#  '1d26ce611ba5722950a983da19c6decf0929f279.sql',
#  '1d650516f00c72e90b20c2e41c5567673ccd3432.sql',
#  '1ddfbe8498a66c131776e24a7bf732484614d62d.sql',
#  '2170d73162a52e888591811df3a9a02d19259a32.sql',
#  '22ecf1641c4b66cfcdf2d6fe9cc1277512681eec.sql',
#  '239e59fa33e5545b183a10f23667650c9b14cc54.sql',
#  '240f278b6fc0a404f4913a8eb5e6682e5b264414.sql',
#  '25377642f94e43939a975e9544c916b1ea6b72c6.sql',
#  '2549a362cdbfcb830c102b48bedaaf85742972aa.sql',
#  '2556dfd6a809c58b2e0f10ed9766e2a3678a190d.sql',
#  '2702fe07dfde795f2beee7e7f4b1cf202aaa5d97.sql',
#  '2a2e41559ecc9823f2688b86c188d40c5ff19741.sql',
#  '2b47a010c117af2d865257f2cdccefd84393b167.sql',
#  '2be449ff9593f16ebda2a75ee59e2b4068850a7d.sql',
#  '2e6a3fee90d6d54df012c51493a43bb8a1fef6e4.sql',
#  '2ffa9a902d817db02403e6d2500a832c7809e986.sql',
#  '305be8ecb4aa020173bd31e25974b8d24a4f0d97.sql',
#  '314fa4c3dda34e446ec3c7ef9ee2b4cd89066021.sql',
#  '31788b6ff4949f9b85d924b0c0071be6376bff3f.sql',
#  '326d3309d770cf93ee9adccd70e7e223342ca9f7.sql',
#  '34f610eb475f90e33dba55ac2b3dcc97fa360c77.sql',
#  '364d884110fa834fa9aeb54562ae11df7d65e4d5.sql',
#  '366184a2d9fcbd8dc3cf1945034b9531173da17c.sql',
#  '3829863fef44161b35ea87a9ad0542337e82d58b.sql',
#  '3855110914c165da409d6198e29c80d757ffddc5.sql',
#  '3adb27f01b9cb4a801bbe3315a49efceba56b8a1.sql',
#  '3b452542ca1cd5f159c09be1e0765122f4d91c7b.sql',
#  '3b4a33a113887baad8d24fd4dc8027f2523d1562.sql',
#  '3d9d4cac4c2b7ac084aea1cd4cd727ceeee3ef7f.s
ca7410ec9cb588753bf4ef3fddd30fb601f3ccea.sql',
#  'cbf8d21d7abd926edd809ac8efee957649396034.sql',
#  'cc5d86d6fa0584e14620f8a45128237ab8976bd0.sql',
#  'ced7dc1df186ba1745e5c67609bd97b52776aa0f.sql',
#  'cedf1edb93465636b0a2eafd8be85e42756592f1.sql',
#  'd021695a07b08e8286379e60f9099ec554dc10b3.sql',
#  'd059ab0576c2dac452c7e3eb689e05569b7e1c43.sql',
#  'd14aac16dfa715053b2156b81f3b8198b858e768.sql',
#  'd4bb9a778d46efad2b6a115c28ce5a0baad1339e.sql',
#  'daac841c8e0653c9a08fddbe2e1dcbc53a6146a3.sql',
#  'db860b447b09b5331a78079bacaf5bac5631589e.sql',
#  'dedea5dbbd21da11f79e403a7a985f3ad77d0397.sql',
#  'e03587379cb250321558af3dca9ad733e1b0307d.sql',
#  'e3739dee7f15d8e1ed7b3e0c1291519b77ddd5a7.sql',
#  'e6d6f8177d60659a285a4f72725448810acd387a.sql',
#  'e79a11647ea86f65e57ba98bd4e835df96eabb4d.sql',
#  'e8a4df3fbcf02634e99bc3c65bf541acafab1960.sql',
#  'e8c7d1255e332854067f44715baa28ab26aa6417.sql',
#  'e9a5ca9162945e768b3b06ede5bfb2cd5ccef9e3.sql',
#  'eabf987f919e2f9867a97a8872dbba95f80e2343.sql',
#  'ee08f4d44aec6b73e6b7c2672606a959f6466314.sql',
#  'eec52bfa3333719e77fe830ce7b3bdd45701c986.sql',
#  'f1397e679ce2255ec2fb8fe465fe1602ddaefc26.sql',
#  'f15180786e467fdf3d9b284dd6689819ad0c3a35.sql',
#  'f2351bdabd713de95b30d1bf7562188fc796d9e2.sql',
#  'f2ba6bab6564daa06705f34b3c15b20977dfff86.sql',
#  'f526254d933493c01257c4c9219824fc92c86d40.sql',
#  'f5306c61228d622bc7a4febc2d5aa2e4f205d9f9.sql',
#  'f65b19ed3cdb1ab85d829e9b1360741be5e7087c.sql',
#  'f73541adef141d3a32cc63d800beab061674f7c7.sql',
#  'f9a5c9ccb40df8bc6131899c9add6e17eb9869eb.sql',
#  'fadf5448b739747d16d98dd2826d8615d64edf65.sql',
#  'fbef83f6bd95855a93688386793bae29fec03af2.sql',
#  'fcc1e4325664af606c8c17becab1d26bb2b29c8d.sql',
#  'fd197a8c8c36cb5a3da6366827c1948da90801f7.sql',
#  'fd609e52d2364b6561ed282834a8a5dba0529958.sql',
#  'fd79ca7b45968ebb273719f6bc2b07567b2e8f49.sql',
#  'fe184c6f0ffcda211aea745521707c07757b1285.sql'}

# %%
tmp = df[df["runtime"] >= 900.0]
print(len(tmp))
print(len(set(tmp["qname"])))
print(set(tmp["qname"]))
# Out:
# 334
# 27
# {'4c24e6c5104b55fb1462bc477487f4c8501f66c2.sql', '31788b6ff4949f9b85d924b0c0071be6376bff3f.sql', '11a83131985d2742cb333582ff7317a80fbcb587.sql', '3829863fef44161b35ea87a9ad0542337e82d58b.sql', '644fd2d5572d784ed63d7f4988241903db09a222.sql', '239e59fa33e5545b183a10f23667650c9b14cc54.sql', '3b4a33a113887baad8d24fd4dc8027f2523d1562.sql', '4b4e960f25e9789d517bc544245e4fc5ba2b2a51.sql', '006ad3e743b877a991463e0149f02e8c349a3c31.sql', '2170d73162a52e888591811df3a9a02d19259a32.sql', 'fd79ca7b45968ebb273719f6bc2b07567b2e8f49.sql', '1ddfbe8498a66c131776e24a7bf732484614d62d.sql', '4e64616ac59a77d52d264fe2e561144297139c30.sql', '49d19ecd559c6cbe26a05eea347eb5582740f300.sql', 'fcc1e4325664af606c8c17becab1d26bb2b29c8d.sql', '2b47a010c117af2d865257f2cdccefd84393b167.sql', '2556dfd6a809c58b2e0f10ed9766e2a3678a190d.sql', '17206e5e52373d88e5618fa92e5dc3f47d0a2df3.sql', '134ee2c0fbd159b41c07050c2b59b6cc5c3593b1.sql', 'a0b8a8ac50b14626db66156236f062a186e3678c.sql', '1a7ffe741a24cc8409450955a238fb71b2a3a1d3.sql', '57d46df2d997ce6a5402ad73596a809f335061df.sql', '4509bc8f86bcbc6b920dd153edfdc26eb214d031.sql', 'bbe909c6b6fc96c534fc5ea93b0a5c36dcae2afa.sql', '0f05350b51ae5ac12ec73d03ceaf618376a9bcbf.sql', '78cd9a4dc70fa8e23f992a986b4af258c0b2a29d.sql', 'f2351bdabd713de95b30d1bf7562188fc796d9e2.sql'}

# %%
qworkloads = {}
for qname in JOB_QNAMES:
    qworkloads[qname] = "JOB"
for qname in CEB_QNAMES:
    qworkloads[qname] = "CEB"
for qname in ERG_QNAMES:
    qworkloads[qname] = "ErgastF1"
for qname in STATS_QNAMES:
    qworkloads[qname] = "Stats"
for qname in JOBLT_QNAMES:
    qworkloads[qname] = "JOB-LT"
for qname in STACK_QNAMES:
    qworkloads[qname] = "Stack"
for qname in TPCH_QNAMES:
    qworkloads[qname] = "TPCH"
    
df["workload"] = df.apply(lambda x: qworkloads[x["qname"]] , axis=1)

df.groupby(["workload", "lt_type"])["runtime"].describe(percentiles=[0.99])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 17
#      14 for qname in TPCH_QNAMES:
#      15     qworkloads[qname] = "TPCH"
# ---> 17 df["workload"] = df.apply(lambda x: qworkloads[x["qname"]] , axis=1)
#      19 df.groupby(["workload", "lt_type"])["runtime"].describe(percentiles=[0.99])
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/frame.py:9558, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9547 from pandas.core.apply import frame_apply
#    9549 op = frame_apply(
#    9550     self,
#    9551     func=func,
#    (...)
#    9556     kwargs=kwargs,
#    9557 )
# -> 9558 return op.apply().__finalize__(self, method="apply")
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/apply.py:741, in FrameApply.apply(self)
#     738 elif self.raw:
#     739     return self.apply_raw()
# --> 741 return self.apply_standard()
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/apply.py:868, in FrameApply.apply_standard(self)
#     867 def apply_standard(self):
# --> 868     results, res_index = self.apply_series_generator()
#     870     # wrap results
#     871     return self.wrap_results(results, res_index)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/apply.py:884, in FrameApply.apply_series_generator(self)
#     881 with option_context("mode.chained_assignment", None):
#     882     for i, v in enumerate(series_gen):
#     883         # ignore SettingWithCopy here in case the user mutates
# --> 884         results[i] = self.f(v)
#     885         if isinstance(results[i], ABCSeries):
#     886             # If we have a view on v, we need to make a copy because
#     887             #  series_generator will swap out the underlying data
#     888             results[i] = results[i].copy(deep=False)
#
# Cell In[22], line 17, in <lambda>(x)
#      14 for qname in TPCH_QNAMES:
#      15     qworkloads[qname] = "TPCH"
# ---> 17 df["workload"] = df.apply(lambda x: qworkloads[x["qname"]] , axis=1)
#      19 df.groupby(["workload", "lt_type"])["runtime"].describe(percentiles=[0.99])
#
# KeyError: '31788b6ff4949f9b85d924b0c0071be6376bff3f.sql'

# %%
jdf = df[df["workload"] == "JOB"]
cdf = df[df["workload"] == "CEB"]

jdf.groupby(["workload", "lt_type"])["runtime"].describe(percentiles=[0.99]).round(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File /usr/local/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'workload'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 jdf = df[df["workload"] == "JOB"]
#       2 cdf = df[df["workload"] == "CEB"]
#       4 jdf.groupby(["workload", "lt_type"])["runtime"].describe(percentiles=[0.99]).round(2)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 'workload'

# %%
df.groupby(["workload", "lt_type"])["runtime"].describe(percentiles=[0.99])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df.groupby(["workload", "lt_type"])["runtime"].describe(percentiles=[0.99])
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/frame.py:8392, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8389     raise TypeError("You have to supply one of 'by' and 'level'")
#    8390 axis = self._get_axis_number(axis)
# -> 8392 return DataFrameGroupBy(
#    8393     obj=self,
#    8394     keys=by,
#    8395     axis=axis,
#    8396     level=level,
#    8397     as_index=as_index,
#    8398     sort=sort,
#    8399     group_keys=group_keys,
#    8400     squeeze=squeeze,
#    8401     observed=observed,
#    8402     dropna=dropna,
#    8403 )
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:959, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     956 if grouper is None:
#     957     from pandas.core.groupby.grouper import get_grouper
# --> 959     grouper, exclusions, obj = get_grouper(
#     960         obj,
#     961         keys,
#     962         axis=axis,
#     963         level=level,
#     964         sort=sort,
#     965         observed=observed,
#     966         mutated=self.mutated,
#     967         dropna=self.dropna,
#     968     )
#     970 self.obj = obj
#     971 self.axis = obj._get_axis_number(axis)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/groupby/grouper.py:889, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     887         in_axis, level, gpr = False, gpr, None
#     888     else:
# --> 889         raise KeyError(gpr)
#     890 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     891     # Add key to exclusions
#     892     exclusions.add(gpr.key)
#
# KeyError: 'workload'

# %%
# tmp = df.groupby(["lt_type", "qname"])["runtime"].mean().reset_index()
# #tmp
# # dfp = tmp.pivot('lt_type', 'lt_type')
# # dfp.corr()

# %%
df.groupby(["qname","lt_type"])["runtime"].describe().sort_values(by="std", ascending=False).head(60)
# Out:
#                                                                 count  \
# qname                                        lt_type
# 006ad3e743b877a991463e0149f02e8c349a3c31.sql m6a_large_mag_8g     3.0
#                                              t4g_large_mag_8g     4.0
# 31788b6ff4949f9b85d924b0c0071be6376bff3f.sql t3_large_gp2_8g      9.0
# 239e59fa33e5545b183a10f23667650c9b14cc54.sql t4g_large_mag_8g     4.0
# 134ee2c0fbd159b41c07050c2b59b6cc5c3593b1.sql t3a_medium_gp3_4g    9.0
# 4e64616ac59a77d52d264fe2e561144297139c30.sql r6a_large_mag_16g    8.0
# 11a83131985d2742cb333582ff7317a80fbcb587.sql m6a_large_mag_8g     3.0
# 4b4e960f25e9789d517bc544245e4fc5ba2b2a51.sql t3_large_gp2_8g      9.0
# 2556dfd6a809c58b2e0f10ed9766e2a3678a190d.sql t4g_large_mag_8g     4.0
# 1a7ffe741a24cc8409450955a238fb71b2a3a1d3.sql m6a_large_mag_8g     5.0
# 17206e5e52373d88e5618fa92e5dc3f47d0a2df3.sql r6a_large_mag_16g    6.0
# 1a7ffe741a24cc8409450955a238fb71b2a3a1d3.sql t4g_large_mag_8g     5.0
# 3adb27f01b9cb4a801bbe3315a49efceba56b8a1.sql m6a_large_mag_8g     4.0
# f2351bdabd713de95b30d1bf7562188fc796d9e2.sql t3_large_gp2_8g     10.0
# 11a83131985d2742cb333582ff7317a80fbcb587.sql t4g_large_mag_8g     5.0
# 78cd9a4dc70fa8e23f992a986b4af258c0b2a29d.sql t3_large_gp2_8g      9.0
# 239e59fa33e5545b183a10f23667650c9b14cc54.sql m6a_large_mag_8g     4.0
# 134ee2c0fbd159b41c07050c2b59b6cc5c3593b1.sql r6a_large_mag_16g    6.0
# 78cd9a4dc70fa8e23f992a986b4af258c0b2a29d.sql r7g_large_gp2_16g   13.0
# 25377642f94e43939a975e9544c916b1ea6b72c6.sql m6a_large_mag_8g     3.0
# 2a2e41559ecc9823f2688b86c188d40c5ff19741.sql m6a_large_mag_8g     3.0
# 3829863fef44161b35ea87a9ad0542337e82d58b.sql t3a_medium_gp3_4g   10.0
# 25377642f94e43939a975e9544c916b1ea6b72c6.sql t4g_large_mag_8g     4.0
# 1a7ffe741a24cc8409450955a238fb71b2a3a1d3.sql r6a_large_mag_16g    6.0
# 3adb27f01b9cb4a801bbe3315a49efceba56b8a1.sql t4g_large_mag_8g     5.0
# 4e64616ac59a77d52d264fe2e561144297139c30.sql t3_large_gp2_8g     10.0
# 4c24e6c5104b55fb1462bc477487f4c8501f66c2.sql t4g_large_mag_8g     4.0
# f2351bdabd713de95b30d1bf7562188fc796d9e2.sql r7g_large_gp2_16g   13.0
# 49d19ecd559c6cbe26a05eea347eb5582740f300.sql r6a_large_mag_16g    7.0
# 4b4e960f25e9789d517bc544245e4fc5ba2b2a51.sql r7g_large_gp2_16g   13.0
# 4c520c9f43febc33412eebb11ab06bf84d652fa6.sql c7g_large_mag_4g     4.0
# 0f05350b51ae5ac12ec73d03ceaf618376a9bcbf.sql r6a_large_mag_16g    6.0
# 2170d73162a52e888591811df3a9a02d19259a32.sql m6a_large_mag_8g     3.0
#                                              r6a_large_mag_16g    8.0
# 2a2e41559ecc9823f2688b86c188d40c5ff19741.sql t4g_large_mag_8g     4.0
#                                              c7g_large_mag_4g     4.0
# 2556dfd6a809c58b2e0f10ed9766e2a3678a190d.sql t3_large_gp2_8g      9.0
# 134ee2c0fbd159b41c07050c2b59b6cc5c3593b1.sql t3_large_gp2_8g     11.0
# 4c520c9f43febc33412eebb11ab06bf84d652fa6.sql c5a_large_mag_4g     3.0
# 006ad3e743b877a991463e0149f02e8c349a3c31.sql c5a_large_mag_4g     3.0
# 130008519a1efd315d28b98b2fe4e71e5c7190c7.sql m6a_large_mag_8g     3.0
# f2351bdabd713de95b30d1bf7562188fc796d9e2.sql t3_xlarge_gp2_16g   13.0
# 2b47a010c117af2d865257f2cdccefd84393b167.sql t3a_medium_gp3_4g   10.0
# 4b4e960f25e9789d517bc544245e4fc5ba2b2a51.sql t3a_medium_gp3_4g   10.0
# 49d19ecd559c6cbe26a05eea347eb5582740f300.sql t3a_medium_gp3_4g   10.0
# 305be8ecb4aa020173bd31e25974b8d24a4f0d97.sql c5a_large_mag_4g     3.0
# 4c520c9f43febc33412eebb11ab06bf84d652fa6.sql m6a_large_mag_8g     3.0
# 2170d73162a52e888591811df3a9a02d19259a32.sql t4g_large_mag_8g     5.0
# 19cd146e1f13d4ef5e5aeedea48afb20497a844d.sql m6a_large_mag_8g     3.0
# 2b47a010c117af2d865257f2cdccefd84393b167.sql t4g_large_mag_8g     5.0
# ced7dc1df186ba1745e5c67609bd97b52776aa0f.sql t4g_large_mag_8g     3.0
# 3829863fef44161b35ea87a9ad0542337e82d58b.sql t3_large_gp2_8g      9.0
# 19cd146e1f13d4ef5e5aeedea48afb20497a844d.sql t4g_large_mag_8g     6.0
# 31788b6ff4949f9b85d924b0c0071be6376bff3f.sql t3a_medium_gp3_4g   10.0
# 3b4a33a113887baad8d24fd4dc8027f2523d1562.sql r6a_large_mag_16g    8.0
# 4dc8bcf9b7c84d46f45ed994fb2db62a33ede2e8.sql t4g_large_mag_8g     4.0
# 2a2e41559ecc9823f2688b86c188d40c5ff19741.sql c5a_large_mag_4g     3.0
# 1cad7ba67ded31b9e21a69986d2bd33796875dc6.sql c5a_large_mag_4g     2.0
# 4b4e960f25e9789d517bc544245e4fc5ba2b2a51.sql t3_xlarge_gp2_16g   13.0
# 006ad3e743b877a991463e0149f02e8c349a3c31.sql c7g_large_mag_4g     4.0
#
#                                                                       mean  \
# qname                                        lt_type
# 006ad3e743b877a991463e0149f02e8c349a3c31.sql m6a_large_mag_8g   472.444978
#                                              t4g_large_mag_8g   471.578566
# 31788b6ff4949f9b85d924b0c0071be6376bff3f.sql t3_large_gp2_8g    464.509032
# 239e59fa33e5545b183a10f23667650c9b14cc54.sql t4g_large_mag_8g   549.703291
# 134ee2c0fbd159b41c07050c2b59b6cc5c3593b1.sql t3a_medium_gp3_4g  587.265996
# 4e64616ac59a77d52d264fe2e561144297139c30.sql r6a_large_mag_16g  657.498224
# 11a83131985d2742cb333582ff7317a80fbcb587.sql m6a_large_mag_8g   610.847439
# 4b4e960f25e9789d517bc544245e4fc5ba2b2a51.sql t3_large_gp2_8g    739.629656
# 2556dfd6a809c58b2e0f10ed9766e2a3678a190d.sql t4g_large_mag_8g   707.329411
# 1a7ffe741a24cc8409450955a238fb71b2a3a1d3.sql m6a_large_mag_8g   494.886069
# 17206e5e52373d88e5618fa92e5dc3f47d0a2df3.sql r6a_large_mag_16g  459.747241
# 1a7ffe741a24cc8409450955a238fb71b2a3a1d3.sql t4g_large_mag_8g   641.890436
# 3adb27f01b9cb4a801bbe3315a49efceba56b8a1.sql m6a_large_mag_8g   297.513664
# f2351bdabd713de95b30d1bf7562188fc796d9e2.sql t3_large_gp2_8g    577.628197
# 11a83131985d2742cb333582ff7317a80fbcb587.sql t4g_large_mag_8g   618.570255
# 78cd9a4dc70fa8e23f992a986b4af258c0b2a29d.sql t3_large_gp2_8g    778.542497
# 239e59fa33e5545b183a10f23667650c9b14cc54.sql m6a_large_mag_8g   657.679440
# 134ee2c0fbd159b41c07050c2b59b6cc5c3593b1.sql r6a_large_mag_16g  532.139359
# 78cd9a4dc70fa8e23f992a986b4af258c0b2a29d.sql r7g_large_gp2_16g  529.651556
# 25377642f94e43939a975e9544c916b1ea6b72c6.sql m6a_large_mag_8g   336.131631
# 2a2e41559ecc9823f2688b86c188d40c5ff19741.sql m6a_large_mag_8g   347.285019
# 3829863fef44161b35ea87a9ad0542337e82d58b.sql t3a_medium_gp3_4g  444.521585
# 25377642f94e43939a975e9544c916b1ea6b72c6.sql t4g_large_mag_8g   193.051775
# 1a7ffe741a24cc8409450955a238fb71b2a3a1d3.sql r6a_large_mag_16g  178.612451
# 3adb27f01b9cb4a801bbe3315a49efceba56b8a1.sql t4g_large_mag_8g   193.158862
# 4e64616ac59a77d52d264fe2e561144297139c30.sql t3_large_gp2_8g    438.474765
# 4c24e6c5104b55fb1462bc477487f4c8501f66c2.sql t4g_large_mag_8g   652.474583
# f2351bdabd713de95b30d1bf7562188fc796d9e2.sql r7g_large_gp2_16g  469.710824
# 49d19ecd559c6cbe26a05eea347eb5582740f300.sql r6a_large_mag_16g  703.075980
# 4b4e960f25e9789d517bc544245e4fc5ba2b2a51.sql r7g_large_gp2_16g  395.636923
# 4c520c9f43febc33412eebb11ab06bf84d652fa6.sql c7g_large_mag_4g   645.757523
# 0f05350b51ae5ac12ec73d03ceaf618376a9bcbf.sql r6a_large_mag_16g  409.254612
# 2170d73162a52e888591811df3a9a02d19259a32.sql m6a_large_mag_8g   723.211293
#                                              r6a_large_mag_16g  284.406930
# 2a2e41559ecc9823f2688b86c188d40c5ff19741.sql t4g_large_mag_8g   314.370453
#                                              c7g_large_mag_4g   660.994572
# 2556dfd6a809c58b2e0f10ed9766e2a3678a190d.sql t3_large_gp2_8g    268.304765
# 134ee2c0fbd159b41c07050c2b59b6cc5c3593b1.sql t3_large_gp2_8g    326.163166
# 4c520c9f43febc33412eebb11ab06bf84d652fa6.sql c5a_large_mag_4g   628.845905
# 006ad3e743b877a991463e0149f02e8c349a3c31.sql c5a_large_mag_4g   718.497086
# 130008519a1efd315d28b98b2fe4e71e5c7190c7.sql m6a_large_mag_8g   321.486143
# f2351bdabd713de95b30d1bf7562188fc796d9e2.sql t3_xlarge_gp2_16g  353.809432
# 2b47a010c117af2d865257f2cdccefd84393b167.sql t3a_medium_gp3_4g  326.429026
# 4b4e960f25e9789d517bc544245e4fc5ba2b2a51.sql t3a_medium_gp3_4g  754.663596
# 49d19ecd559c6cbe26a05eea347eb5582740f300.sql t3a_medium_gp3_4g  420.978269
# 305be8ecb4aa020173bd31e25974b8d24a4f0d97.sql c5a_large_mag_4g   381.057640
# 4c520c9f43febc33412eebb11ab06bf84d652fa6.sql m6a_large_mag_8g   304.264762
# 2170d73162a52e888591811df3a9a02d19259a32.sql t4g_large_mag_8g   714.370984
# 19cd146e1f13d4ef5e5aeedea48afb20497a844d.sql m6a_large_mag_8g   226.150867
# 2b47a010c117af2d865257f2cdccefd84393b167.sql t4g_large_mag_8g   803.563334
# ced7dc1df186ba1745e5c67609bd97b52776aa0f.sql t4g_large_mag_8g   421.270870
# 3829863fef44161b35ea87a9ad0542337e82d58b.sql t3_large_gp2_8g    286.802994
# 19cd146e1f13d4ef5e5aeedea48afb20497a844d.sql t4g_large_mag_8g   193.682090
# 31788b6ff4949f9b85d924b0c0071be6376bff3f.sql t3a_medium_gp3_4g  400.675657
# 3b4a33a113887baad8d24fd4dc8027f2523d1562.sql r6a_large_mag_16g  327.800567
# 4dc8bcf9b7c84d46f45ed994fb2db62a33ede2e8.sql t4g_large_mag_8g   278.570934
# 2a2e41559ecc9823f2688b86c188d40c5ff19741.sql c5a_large_mag_4g
# 19cd146e1f13d4ef5e5aeedea48afb20497a844d.sql m6a_large_mag_8g   387.982122
# 2b47a010c117af2d865257f2cdccefd84393b167.sql t4g_large_mag_8g   909.000000
# ced7dc1df186ba1745e5c67609bd97b52776aa0f.sql t4g_large_mag_8g   540.526927
# 19cd146e1f13d4ef5e5aeedea48afb20497a844d.sql t4g_large_mag_8g   447.166295
# 31788b6ff4949f9b85d924b0c0071be6376bff3f.sql t3a_medium_gp3_4g  613.438933
# 3b4a33a113887baad8d24fd4dc8027f2523d1562.sql r6a_large_mag_16g  458.099133
# 4dc8bcf9b7c84d46f45ed994fb2db62a33ede2e8.sql t4g_large_mag_8g   393.374944
# 2a2e41559ecc9823f2688b86c188d40c5ff19741.sql c5a_large_mag_4g   835.726316
# 1cad7ba67ded31b9e21a69986d2bd33796875dc6.sql c5a_large_mag_4g   889.765247
# 006ad3e743b877a991463e0149f02e8c349a3c31.sql c7g_large_mag_4g   759.292612
# 305be8ecb4aa020173bd31e25974b8d24a4f0d97.sql t4g_large_mag_8g   391.445291
# 3d9d4cac4c2b7ac084aea1cd4cd727ceeee3ef7f.sql m6a_large_mag_8g   367.393289
# 1ddfbe8498a66c131776e24a7bf732484614d62d.sql r6a_large_mag_16g  909.000000
# 3adb27f01b9cb4a801bbe3315a49efceba56b8a1.sql c7g_large_mag_4g   519.680216
# 25377642f94e43939a975e9544c916b1ea6b72c6.sql c7g_large_mag_4g   618.950883
# 4509bc8f86bcbc6b920dd153edfdc26eb214d031.sql m6a_large_mag_8g   800.902083
# 3adb27f01b9cb4a801bbe3315a49efceba56b8a1.sql c5a_large_mag_4g   535.097476
# 3d9d4cac4c2b7ac084aea1cd4cd727ceeee3ef7f.sql t4g_large_mag_8g   437.990106
# fd79ca7b45968ebb273719f6bc2b07567b2e8f49.sql r6a_large_mag_16g  766.969901
# 8f00e094c2a7b30b5ea0d2525e2d5f780b9d6092.sql c7g_large_mag_4g   385.848318
# 130008519a1efd315d28b98b2fe4e71e5c7190c7.sql c5a_large_mag_4g   430.599895
# cc5d86d6fa0584e14620f8a45128237ab8976bd0.sql t4g_large_mag_8g   310.272972
# ca7410ec9cb588753bf4ef3fddd30fb601f3ccea.sql c5a_large_mag_4g   466.036194

# %%
# mintime = min(df["start_time"])
# df["relative_start_time"] = df.apply(lambda x: x["start_time"]-mintime , axis=1)

# %%
sns.lineplot(x=range(len(df["start_time"])), y=df["start_time"].values)
plt.yscale("log")

# %%
print(len(set(df["qname"])))
# Out:
# 180

# %%
tmp = df[df["qname"] == "8a.sql"]
tmp[["relative_start_time", "qname", "runtime"]]
# Out:
# Empty DataFrame
# Columns: [relative_start_time, qname, runtime]
# Index: []

# %%
# tmp1 = df[df["relative_start_time"] < 5800]
# tmp2 = df[df["relative_start_time"] >= 5800]
# tmp2 = tmp2[tmp2["relative_start_time"] < 8000]

# %%
sns.lineplot(x=df["relative_start_time"].values, y=df["runtime"].values)
# Out:
# <AxesSubplot: >

# %%
logfns = glob.iglob(resultdir + "/*/results/sar_logs*")
list(logfns)
# Out:
# ['/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs.csv',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs00',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs07',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs31',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs36',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs09',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs37',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs08',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs30',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs06',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs01',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs23',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs24',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs12',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs15',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs14',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs13',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs25',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs22',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs04',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs03',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs35',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs32',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs33',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs34',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs02',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs05',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs18',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs27',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs20',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs29',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs16',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs11',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs10',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs28',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs17',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs21',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs19',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0aecc0dc52d770d86/results/sar_logs26',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs.csv',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs00',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs07',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs31',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs36',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs09',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs37',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs08',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs30',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs06',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs01',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs23',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs24',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs12',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs15',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs14',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs13',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs25',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs22',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs04',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs03',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs35',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs32',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs33',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs34',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs02',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs05',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs18',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs27',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs20',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs29',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs16',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs11',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs10',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs28',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs17',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs21',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs19',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0a7084c5afd7ef52e/results/sar_logs26',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs.csv',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs00',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs07',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs31',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs36',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs09',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs37',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs08',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs30',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs06',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs01',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs23',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs24',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs12',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs15',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs14',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs13',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs25',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs22',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs04',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs03',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs35',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs32',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs33',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs34',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs02',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs05',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs18',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs27',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs20',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs29',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs16',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs11',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs10',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs28',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs17',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs21',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs19',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-055fa0868f0aa10a4/results/sar_logs26',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs.csv',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs00',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs07',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs31',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs36',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs09',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs37',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs08',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs30',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs06',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs01',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs23',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs24',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs12',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs15',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs14',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs13',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs25',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs22',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs04',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs03',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs35',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs32',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs33',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs34',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs02',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs05',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs18',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs27',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs20',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs29',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs16',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs11',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs10',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs28',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs17',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs21',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs19',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-068901fa01dae9694/results/sar_logs26',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs.csv',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs00',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs07',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs31',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs36',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs09',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs37',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs08',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs30',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs06',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs01',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs23',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs24',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs12',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs15',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs14',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs13',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs25',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs22',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs04',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs03',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs35',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs32',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs33',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs34',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs02',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs05',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs18',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs27',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs20',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs29',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs16',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs11',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs10',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs28',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs17',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs21',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs19',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-00b00c2a14b6b0f55/results/sar_logs26',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs.csv',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs00',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs07',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs31',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs36',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs09',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs37',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs08',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs30',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs06',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs01',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs23',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs24',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs12',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs15',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs14',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs13',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs25',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs22',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs04',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs03',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs35',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs32',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs33',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs34',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs02',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs05',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs18',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs27',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs20',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs29',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs16',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs11',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs10',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs28',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs17',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs21',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs19',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-05ff7a181502041be/results/sar_logs26',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs.csv',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs00',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs07',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs31',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs36',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs09',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs37',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs08',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs30',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs06',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs01',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs23',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs24',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs12',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs15',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs14',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs13',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs25',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs22',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs04',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs03',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs35',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs32',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs33',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs34',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs02',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs05',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs18',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs27',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs20',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs29',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs16',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs11',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs10',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs28',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs17',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs21',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs19',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0917a6319051d3dde/results/sar_logs26',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs.csv',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs00',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs07',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs31',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs36',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs09',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs37',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs08',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs30',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs06',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs01',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs23',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs24',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs12',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs15',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs14',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs13',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs25',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs22',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs04',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs03',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs35',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs32',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs33',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs34',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs02',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs05',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs18',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs27',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs20',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs29',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs16',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs11',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs10',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs28',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs17',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs21',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs19',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0d81df58342c217df/results/sar_logs26',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs.csv',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs00',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs07',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs31',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs36',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs09',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs37',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs08',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs30',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs06',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs01',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs23',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs24',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs12',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs15',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs14',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs13',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs25',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs22',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs04',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs03',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs35',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs32',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs33',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs34',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs02',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs05',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs18',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs27',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs20',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs29',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs16',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs11',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs10',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs28',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs17',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs21',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs19',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0eb7399cd4953b27e/results/sar_logs26',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs.csv',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs00',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs07',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs31',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs36',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs09',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs37',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs08',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs30',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs06',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs01',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs23',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs24',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs12',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs15',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs14',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs13',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs25',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs22',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs04',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs03',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs35',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs32',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs33',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs34',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs02',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs05',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs18',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs27',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs20',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs29',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs16',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs11',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs10',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs28',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs17',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs21',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs19',
#  '/Users/pari/prism-testbed/LatencyCollectorResults/concurrent/exp5-stack-n2/i-0f1027584f0d92e46/results/sar_logs26']

# %%
#logdfs = defaultdict(list)

all_logdfs = {}
for exp in EXP_NAMES:
    #resultdir = os.path.join("/Users/pari/prism-testbed/", "LatencyCollectorResults", "new", exp)
    resultdir = os.path.join("/Users/pari/prism-testbed/", "LatencyCollectorResults", "concurrent", exp)
    #logdfs = {}
    logfns = glob.iglob(resultdir + "/*/results/sar_logs*")
    #print(list(logfns))
    instance_dirs = os.listdir(resultdir)
    for iname in instance_dirs:
        if os.path.isdir(os.path.join(resultdir, iname)):
            all_logdfs[iname] = {}
        else:
            print(iname)
    
    ltdf = pd.read_csv(os.path.join(resultdir, LT_FN), header=None, 
           names=["instance", "lt"])
    ltdf = ltdf.merge(lt_types, on="lt")
    
    for fi, fn in enumerate(logfns):
        instance_name = os.path.basename(os.path.dirname(os.path.dirname(fn)))
        #print(instance_name)
        #all_logdfs[instance_name] = logdfs
        logdfs = all_logdfs[instance_name]

        if ".csv" in fn or "sar_logs00" in fn:
            continue
        try:
            curdf = pd.read_csv(fn, delimiter=";")
            #curdf["instance"] = instance_name
            #curdf = curdf.merge(ltdf, on="instance")
        except Exception as e:
            print("Exception@")
            print(e)
            continue

        if 'kbmemfree' in curdf.keys():
            logdfs["mem"] = curdf
        elif "dropd/s" in curdf.keys():
            logdfs["network1"] = curdf
        elif "%sio-10" in curdf.keys():
            #system load and pressure-stall statistics
            logdfs["pressure_io"] = curdf
        elif 'kbhugfree' in curdf.keys():
            logdfs["hugepg"] = curdf
        elif '%smem-10' in curdf.keys():
            logdfs["pressure_mem"] = curdf
        elif 'kbswpfree' in curdf.keys():
            logdfs["swap"] = curdf
        elif 'idgm6/s' in curdf.keys():
            logdfs["network2"] = curdf
        elif 'bdscd/s' in curdf.keys():
            logdfs["io1"] = curdf
        elif '%irq' in curdf.keys():
            logdfs["cpu_utilization"] = curdf
        elif 'atmptf/s' in curdf.keys():
            logdfs["network3"] = curdf
        elif 'idgm/s' in curdf.keys():
            logdfs["network4"] = curdf
        elif 'areq-sz' in curdf.keys():
            logdfs["device_io"] = curdf
        elif 'call/s' in curdf.keys():
            logdfs["network_nfs"] = curdf
        elif 'rxdrop/s' in curdf.keys():
            logdfs["network5"] = curdf
        elif 'rxcmp/s' in curdf.keys():
            logdfs["network6"] = curdf
        elif 'tcp6sck' in curdf.keys():
            logdfs["network7"] = curdf
        elif 'iseg/s' in curdf.keys():
            logdfs["network8"] = curdf
        elif 'pswpin/s' in curdf.keys():
            logdfs["swap"] = curdf
        elif 'intr/s' in curdf.keys():
            logdfs["interrupts"] = curdf
        elif '%scpu-10' in curdf.keys():
            logdfs["pressure_cpu"] = curdf
        elif 'MHz' in curdf.keys():
            logdfs["power-cpu"] = curdf
        elif 'degC' in curdf.keys():
            logdfs["power-temp"] = curdf
        elif '%ufsused' in curdf.keys():
            logdfs["filesystem"] = curdf
        elif 'cswch/s' in curdf.keys():
            logdfs["context_switch"] = curdf
        elif 'pgpgin/s' in curdf.keys():
            logdfs["paging"] = curdf
        elif 'fwddgm/s' in curdf.keys():
            logdfs["network9"] = curdf
        elif 'ihdrer6/s' in curdf.keys():
            logdfs["network10"] = curdf
        elif 'imsg/s' in curdf.keys():
            logdfs["network11"] = curdf
        elif 'ierr6/s' in curdf.keys():
            logdfs["network12"] = curdf
        elif 'scall/s' in curdf.keys():
            logdfs["network13"] = curdf
        elif 'runq-sz' in curdf.keys():
            logdfs["pressure_load"] = curdf
        elif 'dentunusd' in curdf.keys():
            logdfs["inode"] = curdf
        elif 'igmbq6/s' in curdf.keys():
            logdfs["network14"] = curdf
        elif 'tcpsck' in curdf.keys():
            logdfs["network15"] = curdf
        elif 'otmex/s' in curdf.keys():
            logdfs["network16"] = curdf
        elif 'ihdrerr/s' in curdf.keys():
            logdfs["network17"] = curdf
        elif 'irec6/s' in curdf.keys():
            logdfs["network18"] = curdf
        else:
            assert False
# Out:
# lt_instances.txt

# %%
print("Number of log files: ", len(logdfs))

todel = []
for instance,logdfs in all_logdfs.items():
    keys = list(logdfs.keys())
    tmp = df[df["instance"] == instance]
    if len(tmp) == 0:
        todel.append(instance)
        
for td in todel:
    del all_logdfs[td]

for instance,logdfs in all_logdfs.items():
    print(instance, len(logdfs))
    keys = list(logdfs.keys())
    tmp = df[df["instance"] == instance]

    min_qtime = min(tmp["start_time"].values)
    max_qtime = max(tmp["start_time"].values)

    for k in keys:
        if "network" in k:
            del logdfs[k]
            continue
        if "hugepg" in k:
            del logdfs[k]
            continue

        if len(logdfs[k]) == 0:
            continue

        mincur = min(logdfs[k]["timestamp"])
        logdfs[k]["relative_time"] = logdfs[k].apply(lambda x: x["timestamp"]-min_qtime , axis=1)
        logdfs[k] = logdfs[k][logdfs[k]["relative_time"] >= -10.0]
        
print("Number of log files w/o networking: ", len(logdfs))
# Out:
# Number of log files:  36
# i-0aecc0dc52d770d86 36
# i-0a7084c5afd7ef52e 36
# i-055fa0868f0aa10a4 36
# i-068901fa01dae9694 36
# i-00b00c2a14b6b0f55 36
# i-05ff7a181502041be 36
# i-0917a6319051d3dde 36
# i-0d81df58342c217df 36
# i-0eb7399cd4953b27e 36
# i-0f1027584f0d92e46 36
# Number of log files w/o networking:  16

# %%
for instance,logdfs in all_logdfs.items():
    print(logdfs.keys())
    print(min(logdfs["mem"]["relative_time"]))
# Out:
# dict_keys(['mem', 'pressure_io', 'pressure_mem', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure_cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure_load', 'inode'])
# -2.839749813079834
# dict_keys(['mem', 'pressure_io', 'pressure_mem', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure_cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure_load', 'inode'])
# -5.3948280811309814
# dict_keys(['mem', 'pressure_io', 'pressure_mem', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure_cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure_load', 'inode'])
# -3.045999526977539
# dict_keys(['mem', 'pressure_io', 'pressure_mem', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure_cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure_load', 'inode'])
# -7.728352785110474
# dict_keys(['mem', 'pressure_io', 'pressure_mem', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure_cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure_load', 'inode'])
# -0.8559741973876953
# dict_keys(['mem', 'pressure_io', 'pressure_mem', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure_cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure_load', 'inode'])
# -6.599494934082031
# dict_keys(['mem', 'pressure_io', 'pressure_mem', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure_cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure_load', 'inode'])
# -8.9044508934021
# dict_keys(['mem', 'pressure_io', 'pressure_mem', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure_cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure_load', 'inode'])
# -1.5842630863189697
# dict_keys(['mem', 'pressure_io', 'pressure_mem', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure_cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure_load', 'inode'])
# -2.167469024658203
# dict_keys(['mem', 'pressure_io', 'pressure_mem', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure_cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure_load', 'inode'])
# -8.909898281097412
# dict_keys(['mem', 'pressure_io', 'pressure_mem', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure_cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure_load', 'inode'])
# -8.708908081054688
# dict_keys(['mem', 'pressure_io', 'pressure_mem', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure_cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure_load', 'inode'])
# -9.826273679733276

# %%
print(all_logdfs.keys())
print(set(df["instance"]))
# Out:
# dict_keys(['i-0606bfb433e5561f8', 'i-084d564f783af728b', 'i-0dea2030ca5c3294c', 'i-028a09789b16d9825', 'i-00cd9282e8375fc62', 'i-0544390bd3d5afa85', 'i-007676c1b1e47d2da', 'i-05a0c18d4422472ce', 'i-07728ca07f9aac62f', 'i-0e17cd470d89784cf', 'i-0d101b898c09b1946', 'i-01dad217f13526c56'])
# {'i-07728ca07f9aac62f', 'i-0606bfb433e5561f8', 'i-0d101b898c09b1946', 'i-0544390bd3d5afa85', 'i-01dad217f13526c56', 'i-00cd9282e8375fc62', 'i-0e17cd470d89784cf', 'i-084d564f783af728b', 'i-028a09789b16d9825', 'i-05a0c18d4422472ce', 'i-0dea2030ca5c3294c', 'i-007676c1b1e47d2da'}

# %%
total = 0
for ldf in logdfs:
    print(ldf, logdfs[ldf].keys())
    total += len(logdfs[ldf].keys())

print("Num data points per timestamp: ", total)
# Out:
# mem Index(['# hostname', 'interval', 'timestamp', 'kbmemfree', 'kbavail',
#        'kbmemused', '%memused', 'kbbuffers', 'kbcached', 'kbcommit', '%commit',
#        'kbactive', 'kbinact', 'kbdirty', 'kbanonpg', 'kbslab', 'kbkstack',
#        'kbpgtbl', 'kbvmused', 'relative_time'],
#       dtype='object')
# pressure_io Index(['# hostname', 'interval', 'timestamp', '%sio-10', '%sio-60', '%sio-300',
#        '%sio', '%fio-10', '%fio-60', '%fio-300', '%fio', 'relative_time'],
#       dtype='object')
# pressure_mem Index(['# hostname', 'interval', 'timestamp', '%smem-10', '%smem-60',
#        '%smem-300', '%smem', '%fmem-10', '%fmem-60', '%fmem-300', '%fmem',
#        'relative_time'],
#       dtype='object')
# swap Index(['# hostname', 'interval', 'timestamp', 'pswpin/s', 'pswpout/s',
#        'relative_time'],
#       dtype='object')
# io1 Index(['# hostname', 'interval', 'timestamp', 'tps', 'rtps', 'wtps', 'dtps',
#        'bread/s', 'bwrtn/s', 'bdscd/s', 'relative_time'],
#       dtype='object')
# cpu_utilization Index(['# hostname', 'interval', 'timestamp', 'CPU', '%usr', '%nice', '%sys',
#        '%iowait', '%steal', '%irq', '%soft', '%guest', '%gnice', '%idle',
#        'relative_time'],
#       dtype='object')
# device_io Index(['# hostname', 'interval', 'timestamp', 'DEV', 'tps', 'rkB/s', 'wkB/s',
#        'dkB/s', 'areq-sz', 'aqu-sz', 'await', '%util', 'relative_time'],
#       dtype='object')
# interrupts Index(['# hostname', 'interval', 'timestamp', 'INTR', 'intr/s',
#        'relative_time'],
#       dtype='object')
# pressure_cpu Index(['# hostname', 'interval', 'timestamp', '%scpu-10', '%scpu-60',
#        '%scpu-300', '%scpu', 'relative_time'],
#       dtype='object')
# power-cpu Index(['# hostname', 'interval', 'timestamp', 'CPU', 'MHz', 'relative_time'], dtype='object')
# power-temp Index(['# hostname', 'interval', 'timestamp', 'TEMP', 'DEVICE', 'degC',
#        '%temp', 'relative_time'],
#       dtype='object')
# filesystem Index(['# hostname', 'interval', 'timestamp', 'FILESYSTEM', 'MBfsfree',
#        'MBfsused', '%fsused', '%ufsused', 'Ifree', 'Iused', '%Iused',
#        'relative_time'],
#       dtype='object')
# context_switch Index(['# hostname', 'interval', 'timestamp', 'proc/s', 'cswch/s',
#        'relative_time'],
#       dtype='object')
# paging Index(['# hostname', 'interval', 'timestamp', 'pgpgin/s', 'pgpgout/s',
#        'fault/s', 'majflt/s', 'pgfree/s', 'pgscank/s', 'pgscand/s',
#        'pgsteal/s', '%vmeff', 'relative_time'],
#       dtype='object')
# pressure_load Index(['# hostname', 'interval', 'timestamp', 'runq-sz', 'plist-sz', 'ldavg-1',
#        'ldavg-5', 'ldavg-15', 'blocked', 'relative_time'],
#       dtype='object')
# inode Index(['# hostname', 'interval', 'timestamp', 'dentunusd', 'file-nr',
#        'inode-nr', 'pty-nr', 'relative_time'],
#       dtype='object')
# Num data points per timestamp:  166

# %% [markdown]
# # Interrupts / s

# %%
logdfs["interrupts"].groupby("INTR")["intr/s"].describe()
# Out:
#       count        mean        std    min     25%    50%      75%    max
# INTR
# -1    802.0  242.276197  57.165248  110.8  195.95  250.0  278.175  477.2
#  0    802.0    0.000000   0.000000    0.0    0.00    0.0    0.000    0.0
#  1    802.0    0.000000   0.000000    0.0    0.00    0.0    0.000    0.0
#  2    802.0    0.000000   0.000000    0.0    0.00    0.0    0.000    0.0
#  3    802.0    0.000000   0.000000    0.0    0.00    0.0    0.000    0.0
# ...     ...         ...        ...    ...     ...    ...      ...    ...
#  435  802.0    0.000000   0.000000    0.0    0.00    0.0    0.000    0.0
#  436  802.0    0.000000   0.000000    0.0    0.00    0.0    0.000    0.0
#  437  802.0    0.000000   0.000000    0.0    0.00    0.0    0.000    0.0
#  438  802.0    0.000000   0.000000    0.0    0.00    0.0    0.000    0.0
#  439  802.0    0.000000   0.000000    0.0    0.00    0.0    0.000    0.0
#
# [441 rows x 8 columns]

# %% [markdown]
# # PageFaults / s

# %%
# pgdf = logdfs["paging"]
# sns.lineplot(x=pgdf["relative_time"], y=pgdf["fault/s"].values)

# %%
cdf = logdfs["context_switch"]
sns.lineplot(x=cdf["relative_time"].values, y=cdf["cswch/s"].values)
# Out:
# <AxesSubplot:>

# %%
# powdf = logdfs["power-temp"]
# sns.lineplot(x=range(len(powdf)), y=powdf["degC"].values)

# %%
# powcpu = logdfs["power-cpu"]
# sns.lineplot(x=range(len(powcpu)), y=powcpu["MHz"].values)

# %%
pcpu = logdfs["pressure-cpu"]
sns.lineplot(x=pcpu["relative_time"].values, y=pcpu["%scpu"].values)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-144-fad2eec0c0e4> in <module>
# ----> 1 pcpu = logdfs["pressure-cpu"]
#       2 sns.lineplot(x=pcpu["relative_time"].values, y=pcpu["%scpu"].values)
#
# KeyError: 'pressure-cpu'

# %%
memdf = logdfs["mem"]
sns.lineplot(x=memdf["relative_time"], y=memdf["%memused"].values)
# Out:
# <AxesSubplot:xlabel='relative_time'>

# %%
logdfs.keys()
# Out:
# dict_keys(['mem', 'pressure_io', 'pressure_mem', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure_cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure_load', 'inode'])

# %%
fig,axs = plt.subplots(nrows=1,ncols=1,figsize=(20,6))
sns.lineplot(data=df, x="relative_start_time", y = "runtime", ax=axs)
# Out:
# <AxesSubplot:xlabel='relative_start_time', ylabel='runtime'>

# %%
# tmp = df[df["runtime"] <= 900.0]

# fig,axs = plt.subplots(nrows=1,ncols=1,figsize=(20,6))
# sns.lineplot(data=tmp, x="relative_start_time", y = "runtime", ax=axs)

# %%
# tmp = df[df["runtime"] <= 900.0]

# fig,axs = plt.subplots(nrows=1,ncols=1,figsize=(20,6))
# sns.histplot(data=tmp, x="relative_start_time", y = "runtime", stat="count", bins=1000, ax=axs)

# %%
#tmp = df[df["runtime"] <= 900.0]

fig,ax = plt.subplots(nrows=1,ncols=1,figsize=(10,6))
sns.scatterplot(data=df, x="relative_start_time", y = "runtime", ax=ax, alpha=0.3)
# Out:
# <AxesSubplot:xlabel='relative_start_time', ylabel='runtime'>

# %%
logdfs["device_io"].groupby(["DEV"])["areq-sz"].describe()
# Out:
#              count       mean        std   min   25%   50%   75%    max
# DEV
# loop0       2234.0   0.000000   0.000000  0.00  0.00  0.00   0.0    0.0
# loop1       2234.0   0.000000   0.000000  0.00  0.00  0.00   0.0    0.0
# loop2       2234.0   0.000000   0.000000  0.00  0.00  0.00   0.0    0.0
# loop3       2234.0   0.000000   0.000000  0.00  0.00  0.00   0.0    0.0
# loop4       2234.0   0.000000   0.000000  0.00  0.00  0.00   0.0    0.0
# loop5       2234.0   0.000000   0.000000  0.00  0.00  0.00   0.0    0.0
# nvme0n1     2234.0  27.248133  46.340622  4.36  6.29  9.33  22.0  243.3
# nvme0n1p1   2234.0  27.248133  46.340622  4.36  6.29  9.33  22.0  243.3
# nvme0n1p15  2234.0   0.000000   0.000000  0.00  0.00  0.00   0.0    0.0

# %%
print(min(logdfs["paging"]["timestamp"].values), max(logdfs["paging"]["timestamp"].values))
mins = min(logdfs["paging"]["timestamp"].values)
maxs = max(logdfs["paging"]["timestamp"].values)
# Out:
# 1677652496 1677674826

# %%
print(min(df["start_time"].values), max(df["start_time"].values))
mins2 = min(df["start_time"].values)
maxs2 = max(df["start_time"].values)
# Out:
# 1677652495.8028135 1677674833.5794923

# %%
"Seconds after which we started executing queries: ", mins2 - mins
# Out:
# ('Seconds after which we started executing queries: ', -0.19718647003173828)

# %%
"Seconds after which we finished executing queries: ", maxs - maxs2
# Out:
# ('Seconds after which we finished executing queries: ', -7.5794923305511475)

# %%
"Seconds for total sys logging: ", maxs - mins
# Out:
# ('Seconds for total sys logging: ', 22330)

# %%
"Seconds for total query executions: ", maxs2 - mins2
# Out:
# ('Seconds for total query executions: ', 22337.776678800583)

# %%
print(len(set(df["qname"])))
# Out:
# 146

# %%
# import pandas as pd
# from bokeh.io import curdoc, output_notebook, output_file
# from bokeh.layouts import row, column
# from bokeh.models import Select, DataRange1d, ColumnDataSource
# from bokeh.plotting import figure

# output_notebook()
# # output_file('test.html')

# def get_dataset(src, key):
#     source = ColumnDataSource(data=src)
#     return source


# curdf = logdfs["mem"]
# cc = []
# for key in curdf.keys():
#     if key not in ["# hostname", "interval", "timestamp", "relative_time"]:
#         cc.append(key)

# sel = cc[0]
# # vselect = Select(value=ver, title='Statistic Name', options=sorted((cc)))
# # source = get_dataset(curdf, ver)

# plot = figure(plot_width=500, plot_height = 400, tools="", 
#               toolbar_location=None)
# plot.xaxis.axis_label = 'Unix Seconds'
# plot.yaxis.axis_label = 'Stats'
# plot.axis.axis_label_text_font_style = 'bold'

# plot.grid.grid_line_alpha = 0.3 
# plot.title.text = "System Statistics"

# lines = []
# for key in cc:
#     lines.append(plot.line(x='relative_time', y=key, source=source))
#     lines[-1].visible = False

# select = Select(title="Plot to show:", value=sel, options=cc)

# select.js_on_change("value", CustomJS(args=dict(lines=lines, options=cc), code="""
#     for (let i = 0, len = options.length; i < len; i++) {
#         if (this.value == options[i]) {
#             lines[i].visible = true
#         } else {
#             lines[i].visible = false
#         }
#     }
# """))

# layout = column(select, plot)
# show(layout)

# #show(column(controls, plot))

# %% [markdown]
# # Working code for bokeh

# %%
# import copy
# import pandas as pd
# from bokeh.io import curdoc, output_notebook, output_file
# from bokeh.layouts import row, column
# from bokeh.models import Select, DataRange1d, ColumnDataSource
# from bokeh.plotting import figure

# output_notebook()

# curdf = logdfs["mem"]
# cc = []
# for key in curdf.keys():
#     if key not in ["# hostname", "interval", "timestamp", "relative_time"]:
#         cc.append(key)

# sel = cc[0]

# src = copy.deepcopy(curdf)
# src["to_plot"] = src[sel]
# source = ColumnDataSource(data=src)

# plot = figure(plot_width=500, plot_height = 400, tools="", 
#               toolbar_location=None)
# plot.xaxis.axis_label = 'Unix Seconds'
# plot.yaxis.axis_label = 'Stats'
# plot.axis.axis_label_text_font_style = 'bold'

# plot.grid.grid_line_alpha = 0.3 
# plot.title.text = "System Statistics"

# plot.line(x='relative_time', y="to_plot", source=source)

# select = Select(title="Statistic", value=sel, options=cc)
# select.js_on_change("value", CustomJS(args=dict(source=source, select=select), code="""
#     source.data["to_plot"] = source.data[this.value];
#     source.change.emit()
# """))

# # fig,ax = plt.subplots(nrows=1,ncols=1,figsize=(10,6))
# # sns.scatterplot(data=df, x="relative_start_time", y = "runtime", ax=ax, alpha=0.3)

# layout = column(select, plot)
# show(layout)

# # output_file('test.html')

# %%
import copy
import pandas as pd
from bokeh.io import curdoc, output_notebook, output_file
from bokeh.layouts import row, column
from bokeh.models import Select, DataRange1d, ColumnDataSource, MultiChoice
from bokeh.plotting import figure

def plot_all_instances(all_df):
    
    for instance in all_logdfs:
        
        curlogdfs = all_logdfs[instance]
        df = all_df[all_df["instance"] == instance]
        lttype = df["lt_type"].values[0]
        
        reset_output()
        output_file("Query-System-Logs-{}-{}.html".format(lttype, "imdb2"))

        KEY_ORDER = ["mem", "io1", "device_io", "cpu_utilization", 
                    "pressure_mem", "pressure_io", "pressure_cpu", "pressure_load",
                    "paging", "context_switch", 'interrupts', 'filesystem', 
                     'inode']

        def get_cur_plot(curdf, title, common_xrange, common_x):
            #global common_xrange, common_x

            cc = []
            for key in curdf.keys():
                if key not in ["# hostname", "interval", "timestamp", "relative_time", "DEV", 
                              "FILESYSTEM",]:
                    cc.append(key)

            sel = cc[0]
            src = curdf
            src = src.groupby("relative_time").mean().reset_index()
            src["to_plot"] = src[sel]

            source = ColumnDataSource(data=src)

            plot = figure(plot_width=420, plot_height = 400,
                          x_range = common_xrange,
                         )

            if common_xrange is None:
                common_xrange = plot.x_range
            else:
                source.data["common_relative_time"] = common_x

            plot.xaxis.axis_label = 'Seconds'
            plot.yaxis.axis_label = 'Stat'
            plot.axis.axis_label_text_font_style = 'bold'
            plot.grid.grid_line_alpha = 0.3 
            plot.title.text = title


            if common_x is None:
                plot.line(x='relative_time', y="to_plot", source=source)
                common_x = source.data["relative_time"]
                #common_x = source.data.relative_time
            else:
                plot.line(x="common_relative_time", y="to_plot", source=source)
                #plot.line(x=common_x, y=source.data["to_plot"])

            select = Select(title="Statistic", value=sel, options=cc)
            select.js_on_change("value", CustomJS(args=dict(source=source, select=select), code="""
                source.data["to_plot"] = source.data[this.value];
                source.change.emit()
            """))

            layout = column(select, plot)
            return layout, common_xrange, common_x

        circles = {}
        #df.groupby(["qname"])["runtime"].std().sort_values(by="std", ascending=False).head(60)
        tmp_std = df.groupby(["qname"])["runtime"].std().reset_index().rename(columns={"runtime":"std"})
        
        df = df.merge(tmp_std, on="qname")
        
        hover = HoverTool(tooltips=[
            ('qname', '@qname'),
            ('std', '@std'),
            ('relative_start_time', '@relative_start_time'),
            ('runtime', '@runtime'),
        ])
        
        
        runtime_plot = figure(title = "Query Runtimes", plot_width=1600, plot_height=400, tools=[hover])
        runtime_plot.xaxis.axis_label = 'Seconds'

        allqnames = list(set(df["qname"]))
        for qname in set(df["qname"]):
            tmp = df[df["qname"] == qname]
            rtsource = ColumnDataSource(data=tmp)
            c1 = runtime_plot.circle('relative_start_time','runtime', source=rtsource,
                                     fill_alpha=0.6, size=10)
            c1.visible = True
            circles[qname] = c1

        ### w/o separate circles for scatterplot
        # rtsource = ColumnDataSource(data=df)
        # runtime_plot.circle('relative_start_time','runtime', source=rtsource,fill_alpha=0.5, size=10)

        ### selection area
        multi_choice = MultiChoice(title="Query Selector", value=["all"], options=allqnames + ["all"])
        multi_choice.js_on_change("value", CustomJS(args=dict(circles=circles), code="""
            for (const [key, c1] of Object.entries(circles)) {
                if (this.value.includes("all")) {
                    c1.visible = true
                } else if (this.value.includes(key)) {
                    c1.visible = true
                } else {
                    c1.visible = false
                }
            }
        """))

        plots = []
        
        common_xrange = None
        common_x = None
        
        for key in KEY_ORDER:
            if len(logdfs[key]) == 0:
                continue
            if key in ["swap", "temp"]:
                continue
            p1,common_xrange,common_x = get_cur_plot(curlogdfs[key], key, common_xrange, common_x)
            plots.append(p1)

        show(column(column(multi_choice, runtime_plot), row(plots[0:4]), row(plots[4:8]), row(plots[8:12]), 
                    row(plots[12:16])))
        
plot_all_instances(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 133
#     128             plots.append(p1)
#     130         show(column(column(multi_choice, runtime_plot), row(plots[0:4]), row(plots[4:8]), row(plots[8:12]),
#     131                     row(plots[12:16])))
# --> 133 plot_all_instances(df)
#
# NameError: name 'df' is not defined

# %%
print(len(all_logdfs.keys()))
# Out:
# 12

# %% [markdown]
# # Per query plots

# %%
reset_output()
output_notebook()

reset_output()
#output_notebook()

FN_TMP = "./{EXP_NAME}/{QNAME}.html"
TITLE_FMT = "{QUERY}.\n Start:{START}.\n Latency:{LAT}."
COLS = 2

make_dir(EXP_NAME)

plot_data = {}

for qi, qname in enumerate(list(set(df["qname"]))):
#     if qi >= 2:
#         break
    
    fn = FN_TMP.format(EXP_NAME=EXP_NAME, QNAME=qname.replace(".sql", ""))
    output_file(fn)
    print(fn)
    
    tmp = df[df["qname"] == qname]
    tmp = tmp.sort_values(by="relative_start_time")
    allplots = []
    
    for ei, exp in enumerate(tmp["exp_analyze"].values):
        try:
            plan = eval(str(exp))
            #print(plan)
        except Exception as e:
            print(e)
            continue
        
        lat = tmp["runtime"].values[ei]
        stime = tmp["relative_start_time"].values[ei]
        title = TITLE_FMT.format(QUERY=qname, START=stime, LAT = lat)

        G = explain_to_nx(plan[0][0][0])
        #print(len(G.nodes()))
        aliases = extract_values(plan[0][0][0], "Alias")
        #print(aliases)

        p1 = bokeh_plot(G, showplot=False,  height=600, width=800, title=title)
        p1.visible = True
        allplots.append(p1)
        
    allrows = []
    num_rows = math.ceil(len(allplots) / COLS)
    
    for i in range(num_rows):
        allrows.append(row(allplots[i*COLS:i*COLS+COLS]))
    
    save(column(allrows))
    #show(column(row(allplots[0:3]), row(allplots[3:6]), row(allplots[6:9])))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="542793">Loading BokehJS ...</span>
#     </div>
# ./t7xlarge-gp3-d/29c.html
# ./t7xlarge-gp3-d/25b.html
# ./t7xlarge-gp3-d/23a.html
# ./t7xlarge-gp3-d/2a714.html
# ./t7xlarge-gp3-d/6de21f7b6d08d84073c7496dbff73afba95d7c8d.html
# ./t7xlarge-gp3-d/30b.html
# ./t7xlarge-gp3-d/18a.html
# ./t7xlarge-gp3-d/11d.html
# ./t7xlarge-gp3-d/26b.html
# ./t7xlarge-gp3-d/24b.html
# ./t7xlarge-gp3-d/4a143.html
# ./t7xlarge-gp3-d/32b1cf5e7af7bd6231e2d73a1b56ecf21bbd9804.html
# ./t7xlarge-gp3-d/3a76.html
# ./t7xlarge-gp3-d/7a58.html
# ./t7xlarge-gp3-d/29a.html
# ./t7xlarge-gp3-d/7045b4dac1171674c69f224b25c3c73ad8d9ca03.html
# ./t7xlarge-gp3-d/19a.html
# ./t7xlarge-gp3-d/408f3f94c386672c03af6b01705edab10554bba2.html
# ./t7xlarge-gp3-d/1a972.html
# ./t7xlarge-gp3-d/3a315.html
# ./t7xlarge-gp3-d/1c.html
# ./t7xlarge-gp3-d/16d.html
# ./t7xlarge-gp3-d/2c99.html
# ./t7xlarge-gp3-d/32a.html
# ./t7xlarge-gp3-d/5b.html
# ./t7xlarge-gp3-d/8c.html
# ./t7xlarge-gp3-d/be5f621ca67267a999a86e6b9843728d6992d649.html
# ./t7xlarge-gp3-d/2a620.html
# ./t7xlarge-gp3-d/3ebf44254fc9a2ae77481169131fd0ab111a6c43.html
# ./t7xlarge-gp3-d/f01b2eb575db47e3c4c5f9622d94b5e988ad78d4.html
# ./t7xlarge-gp3-d/31b.html
# ./t7xlarge-gp3-d/11c.html
# ./t7xlarge-gp3-d/17a.html
# ./t7xlarge-gp3-d/22c.html
# ./t7xlarge-gp3-d/1a2493.html
# ./t7xlarge-gp3-d/8a489.html
# ./t7xlarge-gp3-d/4a325.html
# ./t7xlarge-gp3-d/3c.html
# ./t7xlarge-gp3-d/9a.html
# ./t7xlarge-gp3-d/22b.html
# ./t7xlarge-gp3-d/b5a08a81ff95931c299dbc494e82986074308613.html
# ./t7xlarge-gp3-d/2b92.html
# ./t7xlarge-gp3-d/10b.html
# ./t7xlarge-gp3-d/1a2442.html
# ./t7xlarge-gp3-d/1d.html
# ./t7xlarge-gp3-d/22a.html
# ./t7xlarge-gp3-d/1a930.html
# ./t7xlarge-gp3-d/1f4eb208fe38c39bd9323678513a82825ee1a0e2.html
# ./t7xlarge-gp3-d/2b244.html
# ./t7xlarge-gp3-d/3a.html
# ./t7xlarge-gp3-d/55ddc0e7724543235527147bf38f6fe598d64109.html
# ./t7xlarge-gp3-d/b1a7806028abd383d799eddadf7a40ebc9e049a8.html
# ./t7xlarge-gp3-d/4a178.html
# ./t7xlarge-gp3-d/2b190.html
# ./t7xlarge-gp3-d/13b.html
# ./t7xlarge-gp3-d/45c669fe5625a11ad100e6a20d915119b8d56c54.html
# ./t7xlarge-gp3-d/8a190.html
# ./t7xlarge-gp3-d/1a1508.html
# ./t7xlarge-gp3-d/7a131.html
# name 'nan' is not defined
# ./t7xlarge-gp3-d/7a121.html
# ./t7xlarge-gp3-d/2a633.html
# ./t7xlarge-gp3-d/2c278.html
# ./t7xlarge-gp3-d/3a411.html
# ./t7xlarge-gp3-d/16b.html
# ./t7xlarge-gp3-d/9d7d0228ffc0ade657e4194b1d6b33cb2a5353b4.html
# ./t7xlarge-gp3-d/28a.html
# ./t7xlarge-gp3-d/31c.html
# ./t7xlarge-gp3-d/20a.html
# ./t7xlarge-gp3-d/8a400.html
# ./t7xlarge-gp3-d/2a245.html
# ./t7xlarge-gp3-d/8d.html
# ./t7xlarge-gp3-d/30c.html
# ./t7xlarge-gp3-d/6a508.html
# ./t7xlarge-gp3-d/15d.html
# ./t7xlarge-gp3-d/728f1ee9b87457c8b28490639330db5b8f5b1e1c.html
# ./t7xlarge-gp3-d/6a338.html
# ./t7xlarge-gp3-d/61959f7b7fcd01bb21afed4e91a731fb1e4f5a14.html
# ./t7xlarge-gp3-d/1a761.html
# ./t7xlarge-gp3-d/1a1974.html
# ./t7xlarge-gp3-d/e8c1806d3f6d16369058ed9c40cc6b4e2e56676e.html
# ./t7xlarge-gp3-d/2a348.html
# ./t7xlarge-gp3-d/cd252c4d15a8d118c1aae28bd1ec48c7f45584b2.html
# ./t7xlarge-gp3-d/14a.html
# ./t7xlarge-gp3-d/2c192.html
# ./t7xlarge-gp3-d/5a686.html
# ./t7xlarge-gp3-d/7a160.html

# %%
src.groupby("relative_time").mean().reset_index()
# Out:
#       relative_time   timestamp
# 0                 0  1674686716
# 1                10  1674686726
# 2                20  1674686736
# 3                30  1674686746
# 4                40  1674686756
# ...             ...         ...
# 2280          22810  1674709526
# 2281          22820  1674709536
# 2282          22830  1674709546
# 2283          22840  1674709556
# 2284          22850  1674709566
#
# [2285 rows x 2 columns]

# %%
print(logdfs.keys())
print(len(logdfs.keys()))
# Out:
# dict_keys(['mem', 'pressure1', 'pressure2', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure-cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure-load', 'inode'])
# 16

# %%
logdfs["mem"].keys()
# Out:
# Index(['# hostname', 'interval', 'timestamp', 'kbmemfree', 'kbavail',
#        'kbmemused', '%memused', 'kbbuffers', 'kbcached', 'kbcommit', '%commit',
#        'kbactive', 'kbinact', 'kbdirty', 'kbanonpg', 'kbslab', 'kbkstack',
#        'kbpgtbl', 'kbvmused'],
#       dtype='object')

# %%
logdfs.keys()
# Out:
# dict_keys(['mem', 'pressure1', 'hugepg', 'pressure2', 'swap', 'io1', 'cpu_utilization', 'device_io', 'interrupts', 'pressure-cpu', 'power-cpu', 'power-temp', 'filesystem', 'context_switch', 'paging', 'pressure-load', 'inode'])
