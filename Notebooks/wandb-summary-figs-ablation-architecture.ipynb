# %%
import wandb
#from wandb import Api
from collections import defaultdict
import pandas as pd
import numpy as np

import random

import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import HTML
from IPython.display import display_html
import os

import warnings
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
BASELINES = ["DBMS\n(Diff DB,Test Env)", "DBMS\n(Test DB,Test Env)"]

HUES = {}

# Base models
HUES["DBMS\n(Diff DB,Test Env)"] = "Red"  # Red is a strong color, good for contrast.
HUES["DBMS\n(Test DB,Test Env)"] = "Orange"  # Orange is distinct from red and provides good contrast.

# Your model
HUES["Factorized (Osprey)"] = "RoyalBlue"  # A bright and prominent shade of blue.
HUES["Factorized (Pre-trained MLP)"] = "DeepPink"
HUES["Factorized\n(Query History,\n No System Logs)"] = "SlateGray"

# Other GCN models
HUES["GCN\n(Test DB,Diff Env)"] = "LightGreen"  # A lighter shade for distinction from darker colors.
HUES["GCN\n(Diff DB,Test Env)"] = "Cyan"  # Cyan is visually distinct from blue and green.
HUES["GCN\n(Test DB,Test Env)"] = "LightGray"  # A neutral, unobtrusive color for the least focus.

# Factorized models
HUES["Factorized\n(No Pre-training)"] = "YellowGreen"  # A yellow-green shade for differentiation.

# GCN-Transformer models
HUES["GCN-Transformer (TestDB)"] = "SlateGray"  # A neutral color that doesn't dominate.

# %%
api = wandb.Api()

# %%
bruns = api.runs("pari/LatencyPredictor",
    {"$and": [
      {"config.alg": "dbms"},
      {"$or": [
            {"$and": [
                {"tags":"single-final9-min-01-baseline"},
            ]},
      ]} 
    ]
    })

print(f"Found {len(bruns)} runs")
# Out:
# Found 3 runs

# %%
import time
start = time.time()

bdfs = []

cur_run = None
for run in bruns:
    skip = False
    if skip:
        continue
    if run.State != "finished":
        print("not finished!")
        cur_run = run
        continue
    
    data = defaultdict(list)
    data["Tags"].append(run.Tags)
    data["name"].append(run.name)
    
    
    for k,v in run.config.items():
        if not k.startswith("_") or not k.contains("/"):
            data[k].append(v)

    for k,v in run.summary._json_dict.items():
        if k.startswith("_"):
            continue
        if "/" in k:
            continue
        data[k].append(v)
        
    bdfs.append(pd.DataFrame(data))

print("took: ", time.time()-start)
print(len(bdfs))

bdf = pd.concat(bdfs)
#bdf = bdf[bdf["config"] == "configs/baselines/config_dbms_imdb.yaml"]
print(len(bdf))
# Out:
# took:  0.011312007904052734
# 3
# 3

# %%
bdf[["Final-LatencyQError-test-mean", "Final-LatencyQError-test_unseen-mean", "dbms_fit_test"]]
# Out:
#    Final-LatencyQError-test-mean  Final-LatencyQError-test_unseen-mean  \
# 0                      18.042923                             26.897645
# 0                      18.042923                                   NaN
# 0                      20.202283                             17.142025
#
#    dbms_fit_test
# 0              0
# 0              0
# 0              1

# %%
runs = api.runs("pari/LatencyPredictor",
    {"$and": [
      #{"config.eval_epoch": 5},
      #{"config.traindata_dir": "LatencyCollectorResults/background"},
      #{"config.traindata_dir": "LatencyCollectorResults/new"},
      {"$or": [
            {"$or": [
                #{"tags":"imdb-final9-ablations-logfiles"},
                {"tags": "single-final9-min-01"},
                {"tags":"ceb-env-mlp"},
                {"tags":"imdb-final9-ablations"},
                {"tags":"imdb_hist_net"},
            ]},
      ]} 
    ]
    })

print(f"Found {len(runs)} runs")
# Out:
# Found 232 runs

# %%
import time
start = time.time()

dfs = []

cur_run = None
for run in runs:
    skip = False
    if skip:
        continue
    if run.State != "finished":
        cur_run = run
        continue
    
    data = defaultdict(list)
    data["Tags"].append(run.Tags)
    data["name"].append(run.name)
    
    
    for k,v in run.config.items():
        if not k.startswith("_") or not k.contains("/"):
            data[k].append(v)

    for k,v in run.summary._json_dict.items():
        if k.startswith("_"):
            continue
        if "/" in k:
            continue
        data[k].append(v)
        
    dfs.append(pd.DataFrame(data))

print("took: ", time.time()-start)
print(len(dfs))
# Out:
# took:  1.8376951217651367
# 189

# %%
df = pd.concat(dfs)

print(set(df["config"]))

df1 = df[df["config"].str.contains("transfer")]
df1 = df[df["feat_onehot"] == 0]
print("Num transferrable: ", len(df1))

df2 = df[(df["tags"] == "exp1_single,exp2_single,exp3_single,exp7_single_ceb2") &
            (df["split_kind"] == "lt_type-query") &
            ~(df["config"].str.contains("nopretrain"))
        ]

df3 = df[df["config"].str.contains("nopretrain")]
df3 = df3[df3["sys_net_pretrained"] == 0]

print(set(df3["seed"]))
df3 = df3.drop_duplicates(["seed"])
print(len(df3))

df = pd.concat([df1,df2, df3])

df = pd.concat([df, bdf])
print(len(df))
# Out:
# {'configs/evals/concurrent/config_noimdb_mt.yaml', 'configs/evals/single/config_noimdb_transferable.yaml', 'configs/evals/single/config_noimdb_cols.yaml', 'configs/evals/single/config_noimdb_nopretraining.yaml', 'configs/evals/single/config_noimdb_hist.yaml', 'configs/evals/single/config_noimdb.yaml'}
# Num transferrable:  6
# {1, 2, 3, 4}
# 4
# 74

# %%
print(set(df["alg"]))
print(set(df["config"]))
# Out:
# {'nn', 'dbms'}
# {'configs/evals/single/config_noimdb_transferable.yaml', 'configs/evals/single/config_noimdb_cols.yaml', 'configs/evals/single/config_noimdb_nopretraining.yaml', 'configs/evals/single/config_noimdb_hist.yaml', 'configs/baselines/config_dbms_imdb.yaml', 'configs/evals/single/config_noimdb.yaml'}

# %%
# GCN, GCN-Transformer, GCN-Pretrained, GCN-Pretrained-Latent

PRETRAINED_NAME = False

def get_alg(row):
    if "dbms" == row["alg"] or "dbms-c" == row["alg"]:
        if row["dbms_fit_test"]:
            return "DBMS\n(Test DB,Test Env)"
        else:
            return "DBMS\n(Diff DB,Test Env)"
    
    elif "dbms-all" == row["alg"]:
        return "DBMS-all"
    
    elif "avg" in row["config"]:
        return "GCN-Avg"
    
    elif row["arch"] == "gcn":
        if "train_local_model" in row:
            if "train_env_model" in row and str(row["train_env_model"]) != "nan" and row["train_env_model"]:
                print(row["train_env_model"])
                return "GCN\n(Diff DB,Test Env)"
            elif str(row["train_local_model"]) == "nan" or not row["train_local_model"]:
                return "GCN\n(Test DB,Diff Env)"
            else:
                return "GCN\n(Test DB,Test Env)"
        else:
            return "GCN"
    
    elif row["sys_net_pretrained"] == 0:
        if row["extra_training"]:
            return "Factorized\n(No Pre-training)"
        else:
            return "GCN-Transformer (TestDB)"
    elif row["sys_net_arch"] == "mlp":
        return "Factorized (Pre-trained MLP)"
    
    elif "hist" in row["config"]:
        return "Factorized\n(Query History,\n No System Logs)"
    
    elif "evals" in row["config"]:
        if PRETRAINED_NAME:
            pn = row["sys_net_pretrained_fn"]
            mn = "GCN-Pretrained-" + str(row["lr"]) + "extra-training-" + str(row["extra_training"])
            mn += "wd-" + str(row["weight_decay"])
            mn += "-" + pn
            return mn
        else:
            if row["sys_net_pretrained_fn"] == "models4/concurrent_noimdb_randomsplit_test90.wt":
                return "Factorized (Osprey)"
            else:
                return row["sys_net_pretrained_fn"]
    else:
        return None
    
def get_final_alg(row):
    if "dbms" == row["alg"] or "dbms-c" == row["alg"]:
        if row["dbms_fit_test"]:
            return "DBMS\n(Test DB,Test Env)"
        else:
            return "DBMS\n(Diff DB,Test Env)"
    
    elif "dbms-all" == row["alg"]:
        return "DBMS-all"
    
    elif "avg" in row["config"]:
        return "GCN-Avg"
    
    elif row["arch"] == "gcn":
        if "train_local_model" in row:
            if "train_env_model" in row and str(row["train_env_model"]) != "nan" and row["train_env_model"]:
                print(row["train_env_model"])
                return "GCN\n(Diff DB,Test Env)"
            elif str(row["train_local_model"]) == "nan" or not row["train_local_model"]:
                return "GCN\n(Test DB,Diff Env)"
            else:
                return "GCN\n(Test DB,Test Env)"
        else:
            return "GCN"
    
    elif row["sys_net_pretrained"] == 0:
        if row["extra_training"]:
            return "Factorized\n(No Pre-training)"
        else:
            return "GCN-Transformer (TestDB)"
    elif row["sys_net_arch"] == "mlp":
        return "Factorized (Pre-trained MLP)"
    
    elif "hist" in row["config"]:
        return "Factorized\n(Query History,\n No System Logs)"
    
    elif "evals" in row["config"]:
        if PRETRAINED_NAME:
            pn = row["sys_net_pretrained_fn"]
            mn = "GCN-Pretrained-" + str(row["lr"]) + "extra-training-" + str(row["extra_training"])
            mn += "wd-" + str(row["weight_decay"])
            mn += "-" + pn
            return mn
        else:
            if row["sys_net_pretrained_fn"] == "models4/concurrent_noimdb_randomsplit_test90.wt":
                return "Factorized (Osprey)"
            else:
                return row["sys_net_pretrained_fn"]
    else:
        return None
    
def get_workload(row):
    if "dbms" in row["alg"].lower():
        return "IMDb"
    
    if "stack" in row["tags"]:
        return "Stack"
    elif "tpch" in row["tags"]:
        return "Tpch"
    elif "zdb" in row["tags"]:
        return "zdbs"
    else:
        return "IMDb"
    
    
df["Estimator"] = df.apply(lambda x: get_final_alg(x),axis=1)
df["alg"] = df.apply(lambda x: get_alg(x),axis=1)
df["workload"] = df.apply(lambda x: get_workload(x),axis=1)
# Out:
# 1.0
# 3.0
# 6.0
# 2.0
# 5.0
# 4.0
# 1.0
# 3.0
# 6.0
# 2.0
# 5.0
# 4.0

# %%
df = df[df["alg"].notna()]

# %%
print(len(df))
print(set(df["Estimator"]))
print(set(df["num_instances"]))
print(set(df["seed"]))
print(set(df["config"]))
print("pretrain: " , set(df["sys_net_pretrained_fn"]))
print(set(df["alg"]))
print(set(df["tags"]))
print(set(df["workload"]))
print(set(df["tags"]))
print(set(df["seed"]))
print(df.keys())
# Out:
# 74
# {'models4/concurrent_noimdb_logfeats_col_test099.wt', 'Factorized\n(Query History,\n No System Logs)', 'models4/concurrent_noimdb_logfeats_col_test05.wt', 'Factorized (Osprey)', 'models4/concurrent_noimdb_randomsplit_test99.wt', 'GCN\n(Test DB,Test Env)', 'DBMS\n(Diff DB,Test Env)', 'GCN-Transformer (TestDB)', 'Factorized (Pre-trained MLP)', 'GCN\n(Test DB,Diff Env)', 'GCN\n(Diff DB,Test Env)', 'Factorized\n(No Pre-training)', 'DBMS\n(Test DB,Test Env)', 'models4/concurrent_noimdb_logfeats_col_single-instance.wt', 'models4/noactual_mixed_noimdb_logfeats_col.wt', 'models4/concurrent_noimdb_logfeats_col_test09.wt'}
# {1}
# {0, 1, 2, 3, 4}
# {'configs/evals/single/config_noimdb_transferable.yaml', 'configs/evals/single/config_noimdb_cols.yaml', 'configs/evals/single/config_noimdb_nopretraining.yaml', 'configs/evals/single/config_noimdb_hist.yaml', 'configs/baselines/config_dbms_imdb.yaml', 'configs/evals/single/config_noimdb.yaml'}
# pretrain:  {'models4/concurrent_noimdb_mlp.wt', 'models4/concurrent_noimdb_logfeats_col_test099.wt', 'models4/concurrent_noimdb_logfeats_col_test05.wt', 'models4/concurrent_noimdb_randomsplit_test99.wt', 'models4/concurrent_noimdb_logfeats_col_test09.wt', None, 'models4/concurrent_noimdb_randomsplit_test90.wt', 'models4/concurrent_noimdb_rs90.wt', 'models4/concurrent_noimdb_logfeats_col_single-instance.wt', 'models4/noactual_mixed_noimdb_logfeats_col.wt', 'models4/noimdb_log_nostatic_logfeats.wt'}
# {'models4/concurrent_noimdb_logfeats_col_test099.wt', 'Factorized\n(Query History,\n No System Logs)', 'models4/concurrent_noimdb_logfeats_col_test05.wt', 'Factorized (Osprey)', 'models4/concurrent_noimdb_randomsplit_test99.wt', 'GCN\n(Test DB,Test Env)', 'DBMS\n(Diff DB,Test Env)', 'GCN-Transformer (TestDB)', 'Factorized (Pre-trained MLP)', 'GCN\n(Test DB,Diff Env)', 'GCN\n(Diff DB,Test Env)', 'Factorized\n(No Pre-training)', 'DBMS\n(Test DB,Test Env)', 'models4/concurrent_noimdb_logfeats_col_single-instance.wt', 'models4/noactual_mixed_noimdb_logfeats_col.wt', 'models4/concurrent_noimdb_logfeats_col_test09.wt'}
# {'exp5_single_stats,exp8_single_stack,exp9_single_tpch,exp4_single_ergast,exp1_single,exp2_single,exp3_single,exp7_single_ceb2', 'exp1_single,exp2_single,exp3_single,exp7_single_ceb2'}
# {'IMDb', 'Stack'}
# {'exp5_single_stats,exp8_single_stack,exp9_single_tpch,exp4_single_ergast,exp1_single,exp2_single,exp3_single,exp7_single_ceb2', 'exp1_single,exp2_single,exp3_single,exp7_single_ceb2'}
# {0, 1, 2, 3, 4}
# Index(['Tags', 'name', 'lr', 'alg', 'hl1', 'arch', 'seed', 'tags', 'config',
#        'min_est',
#        ...
#        'new_env_unseen-LatencyQError', 'test-LatencyQError', 'test-LatencyMSE',
#        'train-LatencyMSE', 'train-LatencyQError', 'new_env_unseen-LatencyMSE',
#        'test-LatencyRelError', 'train-LatencyRelError', 'Estimator',
#        'workload'],
#       dtype='object', length=258)

# %%
#df = df[df["alg"] != "DBMS-all"]
#df = df[df["alg"] != "GCN-Pretrained-Latent"]

# %%
print(len(df))
df.keys()
# Out:
# 74
# Index(['Tags', 'name', 'lr', 'alg', 'hl1', 'arch', 'seed', 'tags', 'config',
#        'min_est',
#        ...
#        'new_env_unseen-LatencyQError', 'test-LatencyQError', 'test-LatencyMSE',
#        'train-LatencyMSE', 'train-LatencyQError', 'new_env_unseen-LatencyMSE',
#        'test-LatencyRelError', 'train-LatencyRelError', 'Estimator',
#        'workload'],
#       dtype='object', length=258)

# %%
#df = df[df["weight_decay"] == 0.1]

# %%
pd.set_option('display.max_rows', 500)

tmp = df[df["num_instances"] == 1]
tmp[["seed", "num_instances", "alg", "extra_training", "weight_decay", "lr", "Final-LatencyQError-test-mean", "Final-LatencyAE-test-mean" , "weight_decay", "Final-LatencyMSE-test-mean", 
    "Final-LatencyQError-test-median", "Final-LatencyQError-test-99p"]].sort_values(by="seed")
# Out:
#    seed  num_instances                                                alg  \
# 0     0              1                       Factorized (Pre-trained MLP)
# 0     0              1  models4/concurrent_noimdb_logfeats_col_single-...
# 0     0              1    models4/concurrent_noimdb_randomsplit_test99.wt
# 0     0              1      models4/noactual_mixed_noimdb_logfeats_col.wt
# 0     0              1  models4/concurrent_noimdb_logfeats_col_test099.wt
# 0     0              1                           GCN-Transformer (TestDB)
# 0     0              1   models4/concurrent_noimdb_logfeats_col_test05.wt
# 0     0              1                            GCN\n(Test DB,Diff Env)
# 0     0              1   models4/concurrent_noimdb_logfeats_col_test09.wt
# 0     0              1                                Factorized (Osprey)
# 0     0              1                                Factorized (Osprey)
# 0     1              1                           DBMS\n(Diff DB,Test Env)
# 0     1              1  models4/concurrent_noimdb_logfeats_col_test099.wt
# 0     1              1   models4/concurrent_noimdb_logfeats_col_test05.wt
# 0     1              1   models4/concurrent_noimdb_logfeats_col_test09.wt
# 0     1              1                            GCN\n(Test DB,Test Env)
# 0     1              1                            GCN\n(Diff DB,Test Env)
# 0     1              1                            GCN\n(Test DB,Test Env)
# 0     1              1                            GCN\n(Test DB,Test Env)
# 0     1              1                            GCN\n(Test DB,Test Env)
# 0     1              1                            GCN\n(Test DB,Test Env)
# 0     1              1                            GCN\n(Test DB,Diff Env)
# 0     1              1                           GCN-Transformer (TestDB)
# 0     1              1                           DBMS\n(Test DB,Test Env)
# 0     1              1      models4/noactual_mixed_noimdb_logfeats_col.wt
# 0     1              1                      Factorized\n(No Pre-training)
# 0     1              1                           DBMS\n(Diff DB,Test Env)
# 0     1              1                            GCN\n(Test DB,Test Env)
# 0     1              1  models4/concurrent_noimdb_logfeats_col_single-...
# 0     1              1                           DBMS\n(Test DB,Test Env)
# 0     1              1                       Factorized (Pre-trained MLP)
# 0     1              1                                Factorized (Osprey)
# 0     1              1                                Factorized (Osprey)
# 0     1              1                            GCN\n(Diff DB,Test Env)
# 0     1              1                            GCN\n(Diff DB,Test Env)
# 0     1              1                            GCN\n(Diff DB,Test Env)
# 0     1              1    models4/concurrent_noimdb_randomsplit_test99.wt
# 0     1              1                            GCN\n(Diff DB,Test Env)
# 0     1              1                            GCN\n(Diff DB,Test Env)
# 0     1              1      Factorized\n(Query History,\n No System Logs)
# 0     2              1    models4/concurrent_noimdb_randomsplit_test99.wt
# 0     2              1                            GCN\n(Test DB,Diff Env)
# 0     2              1   models4/concurrent_noimdb_logfeats_col_test05.wt
# 0     2              1   models4/concurrent_noimdb_logfeats_col_test09.wt
# 0     2              1  models4/concurrent_noimdb_logfeats_col_single-...
# 0     2              1                                Factorized (Osprey)
# 0     2              1                                Factorized (Osprey)
# 0     2              1      Factorized\n(Query History,\n No System Logs)
# 0     2              1                      Factorized\n(No Pre-training)
# 0     2              1                           GCN-Transformer (TestDB)
# 0     2              1                       Factorized (Pre-trained MLP)
# 0     2              1      models4/noactual_mixed_noimdb_logfeats_col.wt
# 0     2              1  models4/concurrent_noimdb_logfeats_col_test099.wt
# 0     3              1                      Factorized\n(No Pre-training)
# 0     3              1      models4/noactual_mixed_noimdb_logfeats_col.wt
# 0     3              1                           GCN-Transformer (TestDB)
# 0     3              1  models4/concurrent_noimdb_logfeats_col_single-...
# 0     3              1      Factorized\n(Query History,\n No System Logs)
# 0     3              1                       Factorized (Pre-trained MLP)
# 0     3              1                                Factorized (Osprey)
# 0     3              1   models4/concurrent_noimdb_logfeats_col_test09.wt
# 0     3              1   models4/concurrent_noimdb_logfeats_col_test05.wt
# 0     3              1                            GCN\n(Test DB,Diff Env)
# 0     3              1    models4/concurrent_noimdb_randomsplit_test99.wt
# 0     3              1  models4/concurrent_noimdb_logfeats_col_test099.wt
# 0     3              1                                Factorized (Osprey)
# 0     4              1  models4/concurrent_noimdb_logfeats_col_single-...
# 0     4              1                                Factorized (Osprey)
# 0     4              1                      Factorized\n(No Pre-training)
# 0     4              1    models4/concurrent_noimdb_randomsplit_test99.wt
# 0     4              1                       Factorized (Pre-trained MLP)
# 0     4              1      Factorized\n(Query History,\n No System Logs)
# 0     4              1                                Factorized (Osprey)
# 0     4              1  models4/concurrent_noimdb_logfeats_col_test099.wt
#
#   extra_training  weight_decay       lr  Final-LatencyQError-test-mean  \
# 0              0             1  0.00010                       6.676849
# 0              0             1  0.00010                      10.080331
# 0              0             1  0.00010                       5.902248
# 0              0             1  0.00010                       5.541673
# 0              0             1  0.00010                       5.387868
# 0              0             1  0.00010                      10.185368
# 0              0             1  0.00010                       6.413125
# 0              0             1  0.00010                       6.633850
# 0              0             1  0.00010                       5.239281
# 0              0             1  0.00010                       5.410773
# 0              0             1  0.00010                       4.959790
# 0           None             1  0.00010                      18.042923
# 0              0             1  0.00010                      16.128667
# 0              0             1  0.00010                       5.809892
# 0              0             1  0.00010                       6.180979
# 0              0             1  0.00010                       2.771164
# 0              0             1  0.00001                      25.910726
# 0              0             1  0.00010                       3.800529
# 0              0             1  0.00010                      12.098479
# 0              0             1  0.00010                       4.766396
# 0              0             1  0.00010                       2.995714
# 0              0             1  0.00010                      24.206558
# 0              0             1  0.00010                      22.606413
# 0              0             1  0.00010                      20.202283
# 0              0             1  0.00010                       5.878804
# 0              1             1  0.00001                      12.011198
# 0           None             1  0.00010                      18.042923
# 0              0             1  0.00010                       3.491865
# 0              0             1  0.00010                      18.094648
# 0              0             1  0.00010                      20.202283
# 0              0             1  0.00010                       6.483774
# 0              0             1  0.00010                       6.906842
# 0              0             1  0.00010                       6.427200
# 0              0             1  0.00001                      26.326151
# 0              0             1  0.00001                      25.860924
# 0              0             1  0.00001                      27.696711
# 0              0             1  0.00010                       6.193010
# 0              0             1  0.00001                      26.383988
# 0              0             1  0.00001                      32.453214
# 0           None             1  0.00010                      26.809751
# 0              0             1  0.00010                      11.203341
# 0              0             1  0.00010                      16.702872
# 0              0             1  0.00010                       9.397402
# 0              0             1  0.00010                       8.472846
# 0              0             1  0.00010                      14.647590
# 0              0             1  0.00010                       9.831826
# 0              0             1  0.00010                       8.239837
# 0           None             1  0.00010                      20.319921
# 0              1             1  0.00001                      11.254083
# 0              0             1  0.00010                      22.174136
# 0              0             1  0.00010                      15.868305
# 0              0             1  0.00010                       5.970452
# 0              0             1  0.00010                      10.584283
# 0              1             1  0.00001                       6.116087
# 0              0             1  0.00010                       6.159781
# 0              0             1  0.00010                      12.290362
# 0              0             1  0.00010                      10.497674
# 0           None             1  0.00010                      12.230714
# 0              0             1  0.00010                      10.425057
# 0              0             1  0.00010                       6.863669
# 0              0             1  0.00010                       6.096116
# 0              0             1  0.00010                       6.591184
# 0              0             1  0.00010                      13.225617
# 0              0             1  0.00010                       8.027688
# 0              0             1  0.00010                       7.349777
# 0              0             1  0.00010                       7.855822
# 0              0             1  0.00010                       7.224280
# 0              0             1  0.00010                       5.977702
# 0              1             1  0.00001                       6.218046
# 0              0             1  0.00010                       6.843226
# 0              0             1  0.00010                       5.507312
# 0           None             1  0.00010                       7.564512
# 0              0             1  0.00010                       6.653757
# 0              0             1  0.00010                       5.857339
#
#    Final-LatencyAE-test-mean  weight_decay  Final-LatencyMSE-test-mean  \
# 0                  66.515167             1                19761.426881
# 0                  98.643333             1                39217.691956
# 0                  59.935610             1                17041.225542
# 0                  64.873355             1                21555.018850
# 0                  55.622836             1                15685.119407
# 0                  72.295427             1                22647.060558
# 0                  74.529166             1                25929.943062
# 0                  55.665791             1                12902.332990
# 0                  56.594548             1                16161.163358
# 0                  55.230169             1                15103.513613
# 0                  51.506838             1                13027.640699
# 0                  52.384090             1                10841.419676
# 0                 115.634907             1                44672.140722
# 0                  52.529987             1                13358.864202
# 0                  57.692589             1                15476.100585
# 0                   7.101518             1                  892.078480
# 0                  72.336081             1                18185.561205
# 0                  51.801068             1                11192.177077
# 0                 119.444021             1                43403.951936
# 0                  41.952742             1                11736.391717
# 0                  49.560420             1                 9831.999971
# 0                 155.509271             1                62742.354525
# 0                 152.033801             1                69282.536484
# 0                  59.208805             1                10288.468838
# 0                  54.661922             1                14342.496737
# 0                  99.273568             1                37462.870846
# 0                  52.384090             1                10841.419676
# 0                  51.600740             1                12907.672467
# 0                 133.063344             1                56415.990637
# 0                  59.208805             1                10288.468838
# 0                  55.144640             1                12627.896144
# 0                  60.863782             1                16771.091994
# 0                  60.133568             1                16028.878942
# 0                  72.257993             1                18190.914557
# 0                  72.093673             1                18175.300870
# 0                  72.382743             1                18215.612629
# 0                  54.367496             1                13736.473635
# 0                  72.397729             1                18210.569187
# 0                  72.884847             1                18312.241122
# 0                 151.880327             1                61241.032698
# 0                  51.459640             1                12866.779425
# 0                  52.973091             1                13417.608859
# 0                  50.918171             1                12742.999774
# 0                  49.352024             1                12181.311014
# 0                  53.938748             1                13854.922928
# 0                  51.439144             1                13099.612946
# 0                  50.655996             1                12738.386844
# 0                  54.959474             1                14102.299074
# 0                  51.280109             1                13293.862409
# 0                  55.113375             1                14147.249798
# 0                  53.377173             1                13516.046020
# 0                  49.682097             1                12842.066602
# 0                  51.072481             1                12790.289632
# 0                  51.232809             1                12304.182244
# 0                  48.220296             1                11753.766315
# 0                  52.780137             1                13167.817359
# 0                  52.798299             1                13498.472374
# 0                  53.874668             1                13927.364437
# 0                  51.458373             1                12881.965566
# 0                  49.840664             1                12320.483926
# 0                  48.482615             1                11842.645705
# 0                  48.382380             1                11680.014423
# 0                  52.584197             1                13258.127732
# 0                  50.280637             1                12501.709464
# 0                  49.931552             1                12460.488552
# 0                  50.530263             1                12727.191764
# 0                  61.865112             1                16605.841604
# 0                  65.459520             1                20634.809891
# 0                  60.045379             1                16940.879377
# 0                  71.291935             1                22610.298943
# 0                  56.503267             1                14499.439068
# 0                  69.297904             1                19671.619895
# 0                  67.035244             1                20374.269421
# 0                  63.558127             1                19765.663980
#
#    Final-LatencyQError-test-median  Final-LatencyQError-test-99p
# 0                         2.722839                     53.921366
# 0                         3.660086                     95.717359
# 0                         2.612083                     49.157034
# 0                         2.506550                     53.217147
# 0                         2.526996                     43.142443
# 0                         3.285536                     97.345909
# 0                         2.677879                     56.505228
# 0                         2.810073                     53.162519
# 0                         2.487278                     43.687667
# 0                         2.391230                     46.336498
# 0                         2.448435                     34.458387
# 0                         4.467091                    337.890212
# 0                         4.434407                    197.359387
# 0                         2.737839                     50.353443
# 0                         2.812650                     57.476510
# 0                         1.430014                     14.867040
# 0                        10.927795                    255.862614
# 0                         1.912215                     30.364850
# 0                         3.063099                    207.636762
# 0                         2.102326                     40.848835
# 0                         1.710146                     26.969272
# 0                         6.431114                    280.645037
# 0                         5.656178                    277.000839
# 0                         3.736298                    334.147077
# 0                         2.775365                     49.274534
# 0                         3.583627                    133.103965
# 0                         4.467091                    337.890212
# 0                         1.706604                     30.464267
# 0                         4.922646                    237.439676
# 0                         3.736298                    334.147077
# 0                         2.877258                     55.092713
# 0                         2.807871                     62.345381
# 0                         2.801277                     57.139706
# 0                        10.947210                    205.738408
# 0                        10.274786                    225.049739
# 0                        11.349068                    236.894022
# 0                         2.832788                     47.880427
# 0                        10.376620                    219.458846
# 0                        13.240436                    253.044439
# 0                         6.122484                    347.312111
# 0                         3.429188                    128.928172
# 0                         4.064015                    172.027367
# 0                         3.191743                    105.641766
# 0                         2.950509                     93.663297
# 0                         3.984402                    160.175466
# 0                         3.203289                    101.453865
# 0                         2.921714                     93.066785
# 0                         5.342321                    204.883914
# 0                         3.074471                    145.627468
# 0                         5.299862                    230.480402
# 0                         4.254857                    207.949656
# 0                         2.442137                     50.061116
# 0                         3.185689                    112.839083
# 0                         2.841565                     49.092972
# 0                         2.533525                     49.697908
# 0                         3.679321                    123.834241
# 0                         3.299412                    114.386031
# 0                         3.705258                    122.256784
# 0                         3.115127                    138.140442
# 0                         2.766619                     74.235540
# 0                         2.593376                     56.769146
# 0                         2.664817                     72.484912
# 0                         3.659131                    127.826504
# 0                         2.879251                     83.133808
# 0                         2.820402                     73.704577
# 0                         2.891256                     83.543925
# 0                         3.256293                     66.747073
# 0                         2.632802                     53.890780
# 0                         2.714000                     51.047690
# 0                         2.823330                     55.872626
# 0                         2.647325                     42.704065
# 0                         3.000355                     61.239080
# 0                         2.729020                     56.479297
# 0                         2.634933                     48.710501

# %%
print(len(df))
print(set(df["alg"]))
print(set(df["Estimator"]))
# Out:
# 74
# {'models4/concurrent_noimdb_logfeats_col_test099.wt', 'Factorized\n(Query History,\n No System Logs)', 'models4/concurrent_noimdb_logfeats_col_test05.wt', 'Factorized (Osprey)', 'models4/concurrent_noimdb_randomsplit_test99.wt', 'GCN\n(Test DB,Test Env)', 'DBMS\n(Diff DB,Test Env)', 'GCN-Transformer (TestDB)', 'Factorized (Pre-trained MLP)', 'GCN\n(Test DB,Diff Env)', 'GCN\n(Diff DB,Test Env)', 'Factorized\n(No Pre-training)', 'DBMS\n(Test DB,Test Env)', 'models4/concurrent_noimdb_logfeats_col_single-instance.wt', 'models4/noactual_mixed_noimdb_logfeats_col.wt', 'models4/concurrent_noimdb_logfeats_col_test09.wt'}
# {'models4/concurrent_noimdb_logfeats_col_test099.wt', 'Factorized\n(Query History,\n No System Logs)', 'models4/concurrent_noimdb_logfeats_col_test05.wt', 'Factorized (Osprey)', 'models4/concurrent_noimdb_randomsplit_test99.wt', 'GCN\n(Test DB,Test Env)', 'DBMS\n(Diff DB,Test Env)', 'GCN-Transformer (TestDB)', 'Factorized (Pre-trained MLP)', 'GCN\n(Test DB,Diff Env)', 'GCN\n(Diff DB,Test Env)', 'Factorized\n(No Pre-training)', 'DBMS\n(Test DB,Test Env)', 'models4/concurrent_noimdb_logfeats_col_single-instance.wt', 'models4/noactual_mixed_noimdb_logfeats_col.wt', 'models4/concurrent_noimdb_logfeats_col_test09.wt'}

# %%
#df = df[df["seed"] < 4]

# %%
tmp1 = df[~df["config"].str.contains("mt")]
tmp2 = df[df["config"].str.contains("mt")]

# %%
tmp1.groupby(["Estimator"])["Final-LatencyQError-test_unseen-mean"].describe().reset_index().sort_values(by="mean")
# Out:
#                                             Estimator  count       mean  \
# 12   models4/concurrent_noimdb_logfeats_col_test09.wt    4.0   6.235161
# 11   models4/concurrent_noimdb_logfeats_col_test05.wt    4.0   6.495519
# 4                                 Factorized (Osprey)   10.0   6.755366
# 14    models4/concurrent_noimdb_randomsplit_test99.wt    5.0   7.434568
# 8                             GCN\n(Test DB,Test Env)    6.0   7.817048
# 15      models4/noactual_mixed_noimdb_logfeats_col.wt    4.0   8.045303
# 5                        Factorized (Pre-trained MLP)    5.0   9.073792
# 13  models4/concurrent_noimdb_logfeats_col_test099.wt    5.0   9.906065
# 2                       Factorized\n(No Pre-training)    4.0  11.332648
# 10  models4/concurrent_noimdb_logfeats_col_single-...    5.0  13.170249
# 6                             GCN\n(Diff DB,Test Env)    6.0  14.663047
# 3       Factorized\n(Query History,\n No System Logs)    4.0  17.625742
# 7                             GCN\n(Test DB,Diff Env)    4.0  17.727662
# 9                            GCN-Transformer (TestDB)    4.0  21.780444
# 1                            DBMS\n(Test DB,Test Env)    2.0  26.550705
# 0                            DBMS\n(Diff DB,Test Env)    1.0  26.897645
#
#           std        min        25%        50%        75%        max
# 12   0.511418   5.587039   6.044623   6.261322   6.451860   6.830962
# 11   1.277428   5.304435   5.456755   6.420555   7.459319   7.836531
# 4    0.868139   5.773417   6.273267   6.603193   7.161102   8.692348
# 14   1.391300   5.914445   6.723296   6.746562   8.584924   9.203611
# 8    8.497383   2.619695   4.064243   4.662072   5.727414  25.010953
# 15   1.248473   6.966476   7.009583   7.878131   8.913850   9.458473
# 5    2.306981   6.577750   8.216640   8.370079   9.429037  12.775454
# 13   6.509817   5.902796   6.884024   6.884985   8.419266  21.439255
# 2    6.499454   7.600822   8.130044   8.330831  11.533436  21.068109
# 10   5.493679   8.445021   9.533291  12.324390  13.188572  22.359972
# 6    0.947676  13.933278  14.282537  14.367001  14.465646  16.558094
# 3   11.233540   9.805001  10.342022  13.395218  20.678938  33.907532
# 7   10.393941  11.339931  11.913667  13.181321  18.995317  33.208075
# 9    9.381039  11.949290  16.380199  20.579359  25.979603  34.013768
# 1   13.305882  17.142025  21.846365  26.550705  31.255044  35.959384
# 0         NaN  26.897645  26.897645  26.897645  26.897645  26.897645

# %%
tmp1[["seed", "Estimator", "Final-LatencyQError-test_unseen-mean"]]
# Out:
#    seed                                          Estimator  \
# 0     1                            GCN\n(Diff DB,Test Env)
# 0     1                            GCN\n(Diff DB,Test Env)
# 0     1                            GCN\n(Diff DB,Test Env)
# 0     1                            GCN\n(Diff DB,Test Env)
# 0     1                            GCN\n(Diff DB,Test Env)
# 0     1                            GCN\n(Diff DB,Test Env)
# 0     2      Factorized\n(Query History,\n No System Logs)
# 0     4      Factorized\n(Query History,\n No System Logs)
# 0     1      Factorized\n(Query History,\n No System Logs)
# 0     3      Factorized\n(Query History,\n No System Logs)
# 0     3                       Factorized (Pre-trained MLP)
# 0     2                       Factorized (Pre-trained MLP)
# 0     1                       Factorized (Pre-trained MLP)
# 0     4                       Factorized (Pre-trained MLP)
# 0     0                       Factorized (Pre-trained MLP)
# 0     1                                Factorized (Osprey)
# 0     4                                Factorized (Osprey)
# 0     0                                Factorized (Osprey)
# 0     2                                Factorized (Osprey)
# 0     3                                Factorized (Osprey)
# 0     1    models4/concurrent_noimdb_randomsplit_test99.wt
# 0     2    models4/concurrent_noimdb_randomsplit_test99.wt
# 0     4    models4/concurrent_noimdb_randomsplit_test99.wt
# 0     3    models4/concurrent_noimdb_randomsplit_test99.wt
# 0     0    models4/concurrent_noimdb_randomsplit_test99.wt
# 0     2                                Factorized (Osprey)
# 0     3                                Factorized (Osprey)
# 0     0                                Factorized (Osprey)
# 0     4                                Factorized (Osprey)
# 0     1                                Factorized (Osprey)
# 0     3  models4/concurrent_noimdb_logfeats_col_single-...
# 0     4  models4/concurrent_noimdb_logfeats_col_single-...
# 0     1  models4/concurrent_noimdb_logfeats_col_single-...
# 0     0  models4/concurrent_noimdb_logfeats_col_single-...
# 0     2  models4/concurrent_noimdb_logfeats_col_single-...
# 0     3  models4/concurrent_noimdb_logfeats_col_test099.wt
# 0     4  models4/concurrent_noimdb_logfeats_col_test099.wt
# 0     2  models4/concurrent_noimdb_logfeats_col_test099.wt
# 0     0  models4/concurrent_noimdb_logfeats_col_test099.wt
# 0     1  models4/concurrent_noimdb_logfeats_col_test099.wt
# 0     0   models4/concurrent_noimdb_logfeats_col_test05.wt
# 0     3   models4/concurrent_noimdb_logfeats_col_test05.wt
# 0     1   models4/concurrent_noimdb_logfeats_col_test05.wt
# 0     2   models4/concurrent_noimdb_logfeats_col_test05.wt
# 0     2   models4/concurrent_noimdb_logfeats_col_test09.wt
# 0     3   models4/concurrent_noimdb_logfeats_col_test09.wt
# 0     0   models4/concurrent_noimdb_logfeats_col_test09.wt
# 0     1   models4/concurrent_noimdb_logfeats_col_test09.wt
# 0     1                            GCN\n(Test DB,Test Env)
# 0     1                            GCN\n(Test DB,Test Env)
# 0     1                            GCN\n(Test DB,Test Env)
# 0     1                            GCN\n(Test DB,Test Env)
# 0     1                            GCN\n(Test DB,Test Env)
# 0     1                            GCN\n(Test DB,Test Env)
# 0     2                            GCN\n(Test DB,Diff Env)
# 0     0                            GCN\n(Test DB,Diff Env)
# 0     3                            GCN\n(Test DB,Diff Env)
# 0     1                            GCN\n(Test DB,Diff Env)
# 0     1                           GCN-Transformer (TestDB)
# 0     3                           GCN-Transformer (TestDB)
# 0     2                           GCN-Transformer (TestDB)
# 0     0                           GCN-Transformer (TestDB)
# 0     1                           DBMS\n(Test DB,Test Env)
# 0     0      models4/noactual_mixed_noimdb_logfeats_col.wt
# 0     1      models4/noactual_mixed_noimdb_logfeats_col.wt
# 0     2      models4/noactual_mixed_noimdb_logfeats_col.wt
# 0     3      models4/noactual_mixed_noimdb_logfeats_col.wt
# 0     3                      Factorized\n(No Pre-training)
# 0     1                      Factorized\n(No Pre-training)
# 0     4                      Factorized\n(No Pre-training)
# 0     2                      Factorized\n(No Pre-training)
# 0     1                           DBMS\n(Diff DB,Test Env)
# 0     1                           DBMS\n(Diff DB,Test Env)
# 0     1                           DBMS\n(Test DB,Test Env)
#
#    Final-LatencyQError-test_unseen-mean
# 0                             14.270483
# 0                             16.558094
# 0                             14.482428
# 0                             14.415301
# 0                             13.933278
# 0                             14.318700
# 0                             16.269406
# 0                             10.521029
# 0                             33.907532
# 0                              9.805001
# 0                              9.429037
# 0                             12.775454
# 0                              8.216640
# 0                              6.577750
# 0                              8.370079
# 0                              6.607982
# 0                              8.692348
# 0                              6.239942
# 0                              6.598405
# 0                              5.863565
# 0                              5.914445
# 0                              9.203611
# 0                              8.584924
# 0                              6.746562
# 0                              6.723296
# 0                              7.336852
# 0                              6.633850
# 0                              5.773417
# 0                              7.434056
# 0                              6.373242
# 0                              9.533291
# 0                              8.445021
# 0                             22.359972
# 0                             13.188572
# 0                             12.324390
# 0                              6.884024
# 0                              6.884985
# 0                              8.419266
# 0                              5.902796
# 0                             21.439255
# 0                              7.836531
# 0                              5.304435
# 0                              5.507528
# 0                              7.333581
# 0                              6.830962
# 0                              5.587039
# 0                              6.325492
# 0                              6.197151
# 0                              2.619695
# 0                              3.906787
# 0                              6.040706
# 0                             25.010953
# 0                              4.787536
# 0                              4.536609
# 0                             14.257730
# 0                             11.339931
# 0                             12.104912
# 0                             33.208075
# 0                             34.013768
# 0                             11.949290
# 0                             23.301548
# 0                             17.857169
# 0                             35.959384
# 0                              9.458473
# 0                              8.732309
# 0                              6.966476
# 0                              7.023952
# 0                              7.600822
# 0                             21.068109
# 0                              8.306451
# 0                              8.355211
# 0                             26.897645
# 0                                   NaN
# 0                             17.142025

# %%
tmp2.groupby(["Estimator"])["Final-LatencyQError-test_unseen-mean"].describe().reset_index().sort_values(by="mean")
# Out:
# Empty DataFrame
# Columns: [index, count, mean, std, min, 25%, 50%, 75%, max]
# Index: []

# %%
FN_TMP = "NewInstances-{}-{}.pdf"

def plot_metrics(data, metric_median, metric_90p, metric_mean, title, prefix=""):
    fig, axs = plt.subplots(1, 3, figsize=(18,6))
    fig.suptitle(title)
    
    baseline_data = data[data['alg'] == "DBMS (instance-tuned)"]
    
    # Filter out the baseline data from the data being plotted
    data = data[data['alg'] != "DBMS (instance-tuned)"]
    
    if "MSE" in metric_mean:
        use_log = True
    else:
        use_log = False
    
    if not baseline_data.empty:
        baseline_median = baseline_data[metric_median].values[0]
        baseline_90p = baseline_data[metric_90p].values[0]
        baseline_mean = baseline_data[metric_mean].values[0]
    else:
        baseline_median = None
        baseline_90p = None
        baseline_mean = None

    # Plot for Median values
    sns.barplot(data=data, y=metric_median, x="num_instances", hue="Estimator", dodge=True, ax=axs[0])
    if baseline_median is not None:
        axs[0].axhline(baseline_median, color='r', linestyle='--', label='Baseline (Median)')
    axs[0].set_title('Median')

    if use_log:
        axs[0].set_yscale("log")
        
        
    # Plot for 90th Percentile values
    sns.barplot(data=data, y=metric_90p, x="num_instances", hue="Estimator", dodge=True, ax=axs[1])
    if baseline_median is not None:
        axs[1].axhline(baseline_90p, color='r', linestyle='--', label='Baseline (90th Percentile)')
    axs[1].set_title('90th Percentile')
    #if should_use_log_scale(data[metric_90p]):
        
    if use_log:
        axs[1].set_yscale("log")

    # Plot for Mean values
    sns.barplot(data=data, y=metric_mean, x="num_instances", hue="Estimator", dodge=True, ax=axs[2])
    if baseline_median is not None:
        axs[2].axhline(baseline_mean, color='r', linestyle='--', label='Baseline (Mean)')
        
    axs[2].set_title('Mean')
    if use_log:
        axs[2].set_yscale("log")


    # Remove individual legends and add a single legend at the top
    for ax in axs:
        ax.get_legend().remove()
    handles, labels = axs[0].get_legend_handles_labels()
    fig.legend(handles + [axs[0].lines[0]], labels + ['Baseline'], loc='upper center', 
               bbox_to_anchor=(0.5, 1.10), ncol=3)

    # Finalize the plot and save
    plt.tight_layout()
    fn = FN_TMP.format(prefix + "IMDb", title.replace(' ', '-'))
    print(fn)
    plt.savefig(fn, bbox_inches="tight")

# %%
# tmp = df
# # Plot for MSE
# plot_metrics(tmp, 
#              'Final-LatencyMSE-test-median', 
#              'Final-LatencyMSE-test-90p', 
#              'Final-LatencyMSE-test-mean',
#              'Latency MSE', 
#              prefix="SeenQ-")

# # Plot for Q-Error
# plot_metrics(tmp, 
#              'Final-LatencyQError-test-median', 
#              'Final-LatencyQError-test-90p', 
#              'Final-LatencyQError-test-mean',
#              'Latency Q-Error',
#               prefix="SeenQ-")

# plot_metrics(tmp, 
#              'Final-LatencyRelError-test-median', 
#              'Final-LatencyRelError-test-90p', 
#              'Final-LatencyRelError-test-mean',
#              'Latency Relative Error',
#              prefix="SeenQ-")

# # Plot for AE
# plot_metrics(tmp, 
#              'Final-LatencyAE-test-median', 
#              'Final-LatencyAE-test-90p', 
#              'Final-LatencyAE-test-mean',
#              'Latency Absolute Error',
#               prefix="SeenQ-")

# %%
tmp = df
# Plot for MSE
# plot_metrics(tmp, 
#              'Final-LatencyMSE-test_unseen-median', 
#              'Final-LatencyMSE-test_unseen-90p', 
#              'Final-LatencyMSE-test_unseen-mean',
#              'Latency MSE',
#              prefix="UnseenQ")
    

# Plot for Q-Error
# plot_metrics(tmp, 
#              'Final-LatencyQError-test_unseen-median', 
#              'Final-LatencyQError-test_unseen-90p', 
#              'Final-LatencyQError-test_unseen-mean',
#              'Latency Q-Error',
#                  prefix="UnseenQ")

# plot_metrics(tmp, 
#              'Final-LatencyRelError-test_unseen-median', 
#              'Final-LatencyRelError-test_unseen-90p', 
#              'Final-LatencyRelError-test_unseen-mean',
#              'Latency Relative Error',
#                     prefix="UnseenQ")

# Plot for AE
# plot_metrics(tmp, 
#              'Final-LatencyAE-test_unseen-median', 
#              'Final-LatencyAE-test_unseen-90p', 
#              'Final-LatencyAE-test_unseen-mean',
#              'Latency Absolute Error',
#                  prefix="UnseenQ")

# %%
# print(set(df["only_workload"]))

# WKS = ["ssb", "ccs", "accidents", "airline"]
# fig,axs = plt.subplots(nrows=1,ncols=4, figsize=(12,5))

# for wi,wk in enumerate(WKS):
#     ax = axs[wi]
#     tmp = df[df["only_workload"] == wk]
#     sns.barplot(data=tmp, x="alg", y='Final-LatencyQError-test_unseen-mean', 
#                 hue="alg", 
#                 dodge=False, ax=ax)
#     ax.legend().remove()

# %%
# import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.patches as mpatches

ORDER = ["Factorized (Osprey)", "Factorized (Pre-trained MLP)", "Factorized\n(No Pre-training)", 
         "Factorized\n(Query History,\n No System Logs)",
        ]

# Assuming df, BASELINES, HUES, and ORDER are defined somewhere in your script

tmp = df[df["Estimator"].isin(ORDER+BASELINES)]
print(len(tmp))
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

# Manually create legend handles for the bar plots
bar_handles = [mpatches.Patch(color=HUES[name], label=name) for name in ORDER]

# First subplot
ax = axs[0]

# Plot the bars
sns.barplot(data=tmp, x="Estimator", 
            y='Final-LatencyQError-test_unseen-median', 
            hue="Estimator", 
            palette=HUES,
            order=ORDER,
            dodge=False, ax=ax)

# Baseline lines
baseline_handles = []
for estb in BASELINES:
    tmp2 = tmp[tmp["Estimator"] == estb]
    if len(tmp2) == 0:
        continue
    bmedian = tmp2['Final-LatencyQError-test_unseen-median'].mean()
    line = ax.axhline(bmedian, color=HUES[estb], linestyle='--')
    baseline_handles.append(line)

ax.set_xlabel("")
ax.set_xticklabels([])
ax.set_ylabel("Median QError", fontsize=16)
ax.tick_params(axis='y', labelsize=14)  # Set the font size to 12 for y-axis ticks
#ax.set_ylim([1, 10])

ax.legend().remove()  # Remove the auto-generated legend
ax.spines['top'].set_visible(False) 

# Second subplot
ax = axs[1]

sns.barplot(data=tmp, x="Estimator", 
            y='Final-LatencyQError-test_unseen-mean', 
            hue="Estimator", 
            palette=HUES,
            order=ORDER,
            dodge=False, ax=ax)

ax.set_xticklabels([])
ax.set_xlabel("")
ax.set_ylabel("Mean QError", fontsize=16)
ax.tick_params(axis='y', labelsize=14)  # Set the font size to 12 for y-axis ticks

for estb in BASELINES:
    tmp2 = tmp[tmp["Estimator"] == estb]
    if len(tmp2) == 0:
        continue
    bmean = tmp2['Final-LatencyQError-test_unseen-mean'].mean()
    ax.axhline(bmean, color=HUES[estb], linestyle='--')
    
ax.spines['top'].set_visible(False) 
    
#ax.set_ylim([1, 50])

ax.legend().remove()  # Remove the auto-generated legend

# Manually create the legend
if baseline_handles:
    custom_handles = bar_handles + baseline_handles 
    custom_labels = ORDER + BASELINES
else:
    custom_handles = bar_handles
    custom_labels = ORDER

fig.legend(handles=custom_handles, labels=custom_labels, 
           loc='upper center', 
           fontsize=14,
           ncol=3, 
           bbox_to_anchor=(0.5, 1.15),
           frameon=False)

plt.tight_layout()
plt.savefig("EvalSingle-IMDb.pdf", bbox_inches="tight")
# Out:
# 27

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.patches as mpatches

#ORDER = ["Factorized (Osprey)", "Factorized (Pre-trained MLP)", "Factorized\n(No Pre-training)"]

ORDER = ["Factorized (Osprey)", "Factorized (Pre-trained MLP)", "Factorized\n(No Pre-training)", 
         "Factorized\n(Query History,\n No System Logs)",
        ]

# Assuming df, BASELINES, HUES, and ORDER are defined somewhere in your script

tmp = df[df["Estimator"].isin(ORDER)]

# Create the plot
plt.figure(figsize=(5, 4))  # Adjust the size as needed
ax = plt.gca()

# Plot the bars
sns.barplot(data=tmp, x="Estimator", 
            y='Final-LatencyQError-test_unseen-mean', 
            hue="Estimator", 
            palette=HUES,
            order=ORDER,
            dodge=False, ax=ax)

# Baseline lines
baseline_handles = []
for estb in BASELINES:
    tmp2 = tmp[tmp["Estimator"] == estb]
    if len(tmp2) == 0:
        continue
    bmean = tmp2['Final-LatencyQError-test_unseen-mean'].mean()
    line = ax.axhline(bmean, color=HUES[estb], linestyle='--')
    baseline_handles.append(line)

    
ax.set_ylabel("Mean QError", fontsize=16)
ax.tick_params(axis='x', length=0)  # Removing x-axis ticks
ax.set_xticks([])
ax.set_xlabel("Estimator", fontsize=14)  # Removing the x-axis label
ax.tick_params(axis='y', labelsize=14)


#ax.spines['top'].set_visible(False)

# Manually create legend handles for the bar plots
bar_handles = [mpatches.Patch(color=HUES[name], label=name) for name in ORDER]

# Combine custom handles
custom_handles = bar_handles + baseline_handles 
custom_labels = ORDER

# Create the legend
ax.legend(handles=custom_handles, labels=custom_labels, 
          fontsize=14, loc='upper left', frameon=False)

plt.tight_layout()
plt.savefig("Eval-Architectures-IMDb.pdf", bbox_inches="tight")
plt.show()

# %%
set(df["Estimator"])
# Out:
# {'DBMS\n(Diff DB,Test Env)',
#  'DBMS\n(Test DB,Test Env)',
#  'Factorized\n(No Pre-training)',
#  'Factorized\n(Query History,\n No System Logs)',
#  'Factorized (Osprey)',
#  'Factorized (Pre-trained MLP)',
#  'GCN\n(Diff DB,Test Env)',
#  'GCN\n(Test DB,Diff Env)',
#  'GCN\n(Test DB,Test Env)',
#  'GCN-Transformer (TestDB)',
#  'models4/concurrent_noimdb_logfeats_col_single-instance.wt',
#  'models4/concurrent_noimdb_logfeats_col_test05.wt',
#  'models4/concurrent_noimdb_logfeats_col_test09.wt',
#  'models4/concurrent_noimdb_logfeats_col_test099.wt',
#  'models4/concurrent_noimdb_randomsplit_test99.wt',
#  'models4/noactual_mixed_noimdb_logfeats_col.wt'}

# %%
import matplotlib.pyplot as plt
import seaborn as sns

FN_TMP = "NewInstances-{}-{}.pdf"

# Define a function to check if the values have a large range and should be plotted in log scale
def should_use_log_scale(values):
    return max(values) / min(values) > 1000  # Adjust this threshold if needed
    
import seaborn as sns
import matplotlib.pyplot as plt

def plot_metrics2(data, metric_median, metric_90p, metric_mean, title):
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))
    fig.suptitle(title)

    # Filter out the baseline data
    baseline_data = data[data['alg'] == "DBMS (instance-tuned)"]
    #data = data[data['alg'] != "DBMS (instance-tuned)"]

    if not baseline_data.empty:
        baseline_median = baseline_data[metric_median].values[0]
        baseline_90p = baseline_data[metric_90p].values[0]
        baseline_mean = baseline_data[metric_mean].values[0]
    else:
        baseline_median = None
        baseline_90p = None
        baseline_mean = None

    metrics = [(metric_median, baseline_median, 'Median'),
               (metric_90p, baseline_90p, '90th Percentile'),
               (metric_mean, baseline_mean, 'Mean')]

    algs = data['alg'].unique()
    colors = sns.color_palette("tab10", len(algs))
    alg_color_map = dict(zip(algs, colors))
    
    bar_width = 0.15
    num_algs = len(algs)
    positions = list(range(len(data['num_instances'].unique())))

    for i, (metric, baseline, metric_name) in enumerate(metrics):
        ax = axs[i]
        for j, alg in enumerate(algs):
            alg_data = data[data['alg'] == alg]
            
            # Positional adjustments for the bars based on their order
            pos = [p + j * bar_width for p in positions]
            
            mean_values = alg_data.groupby("num_instances")[metric].mean()
            min_values = alg_data.groupby("num_instances")[metric].min()
            max_values = alg_data.groupby("num_instances")[metric].max()
            yerr = [mean_values - min_values, max_values - mean_values]
            
            ax.bar(pos, mean_values, bar_width, yerr=yerr, align='center',
                   alpha=0.7, ecolor='black', capsize=10, label=alg, color=alg_color_map[alg])

        if baseline is not None:
            ax.axhline(baseline, color='r', linestyle='--', label='Baseline ({})'.format(metric_name))
        
        ax.set_title(metric_name)
        ax.set_xlabel('Number of Instances')
        ax.set_ylabel(title)
        ax.yaxis.grid(True)
        ax.set_xticks([p + bar_width * (num_algs-1)/2 for p in positions])
        ax.set_xticklabels([1, 2, 3, 4])

    handles, labels = axs[0].get_legend_handles_labels()
    fig.legend(handles + [axs[0].lines[0]], labels + ['Baseline'], loc='upper center', bbox_to_anchor=(0.5, 1.10), ncol=(len(handles) + 1) // 3)
    
    plt.tight_layout()
    fn = FN_TMP.format("IMDb", title.replace(' ', '-'))
    #plt.savefig(fn, bbox_inches="tight")


# Loop through each unique workload
# for wk in set(df["workload"]):
#     tmp = df[df["workload"] == wk]

# %%
    
tmp = df
# Plot for MSE
plot_metrics(tmp, 
             'Final-LatencyMSE-test-median', 
             'Final-LatencyMSE-test-90p', 
             'Final-LatencyMSE-test-mean',
             'Latency MSE')

# Plot for Q-Error
plot_metrics(tmp, 
             'Final-LatencyQError-test-median', 
             'Final-LatencyQError-test-90p', 
             'Final-LatencyQError-test-mean',
             'Latency Q-Error')

plot_metrics(tmp, 
             'Final-LatencyRelError-test-median', 
             'Final-LatencyRelError-test-90p', 
             'Final-LatencyRelError-test-mean',
             'Latency Relative Error')

# Plot for AE
plot_metrics(tmp, 
             'Final-LatencyAE-test-median', 
             'Final-LatencyAE-test-90p', 
             'Final-LatencyAE-test-mean',
             'Latency Absolute Error')
# Out:
# NewInstances-IMDb-Latency-MSE.pdf
# NewInstances-IMDb-Latency-Q-Error.pdf
# NewInstances-IMDb-Latency-Relative-Error.pdf
# NewInstances-IMDb-Latency-Absolute-Error.pdf

# %%
# Loop through each unique workload
# for wk in set(df["workload"]):
#     tmp = df[df["workload"] == wk]
    
tmp = df
# Plot for MSE
plot_metrics(tmp, 
             'Final-LatencyMSE-test_useen-median', 
             'Final-LatencyMSE-test_useen-90p', 
             'Final-LatencyMSE-test_useen-mean',
             'Latency MSE')

# Plot for Q-Error
plot_metrics(tmp, 
             'Final-LatencyQError-test_useen-median', 
             'Final-LatencyQError-test_useen-90p', 
             'Final-LatencyQError-test_useen-mean',
             'Latency Q-Error')

plot_metrics(tmp, 
             'Final-LatencyRelError-test_useen-median', 
             'Final-LatencyRelError-test_useen-90p', 
             'Final-LatencyRelError-test_useen-mean',
             'Latency Relative Error')

# Plot for AE
plot_metrics(tmp, 
             'Final-LatencyAE-test_useen-median', 
             'Final-LatencyAE-test_useen-90p', 
             'Final-LatencyAE-test_useen-mean',
             'Latency Absolute Error')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 7
#       5 tmp = df
#       6 # Plot for MSE
# ----> 7 plot_metrics(tmp,
#       8              'Final-LatencyMSE-test_useen-median',
#       9              'Final-LatencyMSE-test_useen-90p',
#      10              'Final-LatencyMSE-test_useen-mean',
#      11              'Latency MSE')
#      13 # Plot for Q-Error
#      14 plot_metrics(tmp,
#      15              'Final-LatencyQError-test_useen-median',
#      16              'Final-LatencyQError-test_useen-90p',
#      17              'Final-LatencyQError-test_useen-mean',
#      18              'Latency Q-Error')
#
# Cell In[77], line 26, in plot_metrics(data, metric_median, metric_90p, metric_mean, title, prefix)
#      23     baseline_mean = None
#      25 # Plot for Median values
# ---> 26 sns.barplot(data=data, y=metric_median, x="num_instances", hue="alg", dodge=True, ax=axs[0])
#      27 if baseline_median is not None:
#      28     axs[0].axhline(baseline_median, color='r', linestyle='--', label='Baseline (Median)')
#
# File /usr/local/lib/python3.10/site-packages/seaborn/categorical.py:2753, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2750 if estimator is len:
#    2751     estimator = "size"
# -> 2753 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2754                       estimator, errorbar, n_boot, units, seed,
#    2755                       orient, color, palette, saturation,
#    2756                       width, errcolor, errwidth, capsize, dodge)
#    2758 if ax is None:
#    2759     ax = plt.gca()
#
# File /usr/local/lib/python3.10/site-packages/seaborn/categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File /usr/local/lib/python3.10/site-packages/seaborn/categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'Final-LatencyMSE-test_useen-median'

# %%
# Plot for MSE
plot_metrics2(tmp, 
             'Final-LatencyMSE-test-median', 
             'Final-LatencyMSE-test-90p', 
             'Final-LatencyMSE-test-mean',
             'Latency MSE')

# Plot for Q-Error
plot_metrics2(tmp, 
             'Final-LatencyQError-test-median', 
             'Final-LatencyQError-test-90p', 
             'Final-LatencyQError-test-mean',
             'Latency Q-Error')

plot_metrics2(tmp, 
             'Final-LatencyRelError-test-median', 
             'Final-LatencyRelError-test-90p', 
             'Final-LatencyRelError-test-mean',
             'Latency Relative Error')

# Plot for AE
plot_metrics2(tmp, 
             'Final-LatencyAE-test-median', 
             'Final-LatencyAE-test-90p', 
             'Final-LatencyAE-test-mean',
             'Latency Absolute Error')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 2
#       1 # Plot for MSE
# ----> 2 plot_metrics2(tmp,
#       3              'Final-LatencyMSE-test-median',
#       4              'Final-LatencyMSE-test-90p',
#       5              'Final-LatencyMSE-test-mean',
#       6              'Latency MSE')
#       8 # Plot for Q-Error
#       9 plot_metrics2(tmp,
#      10              'Final-LatencyQError-test-median',
#      11              'Final-LatencyQError-test-90p',
#      12              'Final-LatencyQError-test-mean',
#      13              'Latency Q-Error')
#
# Cell In[80], line 66, in plot_metrics2(data, metric_median, metric_90p, metric_mean, title)
#      64     ax.yaxis.grid(True)
#      65     ax.set_xticks([p + bar_width * (num_algs-1)/2 for p in positions])
# ---> 66     ax.set_xticklabels([1, 2, 3, 4])
#      68 handles, labels = axs[0].get_legend_handles_labels()
#      69 fig.legend(handles + [axs[0].lines[0]], labels + ['Baseline'], loc='upper center', bbox_to_anchor=(0.5, 1.10), ncol=(len(handles) + 1) // 3)
#
# File /usr/local/lib/python3.10/site-packages/matplotlib/axes/_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/matplotlib/axis.py:1968, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1966 if fontdict is not None:
#    1967     kwargs.update(fontdict)
# -> 1968 return self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/matplotlib/axis.py:1890, in Axis.set_ticklabels(self, ticklabels, minor, **kwargs)
#    1886 if isinstance(locator, mticker.FixedLocator):
#    1887     # Passing [] as a list of ticklabels is often used as a way to
#    1888     # remove all tick labels, so only error for > 0 ticklabels
#    1889     if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1890         raise ValueError(
#    1891             "The number of FixedLocator locations"
#    1892             f" ({len(locator.locs)}), usually from a call to"
#    1893             " set_ticks, does not match"
#    1894             f" the number of ticklabels ({len(ticklabels)}).")
#    1895     tickd = {loc: lab for loc, lab in zip(locator.locs, ticklabels)}
#    1896     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (1), usually from a call to set_ticks, does not match the number of ticklabels (4).

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# # Example data for 3 baselines and 5 seeds for each baseline
# baseline_names = ["Baseline1", "Baseline2", "Baseline3"]
# baseline_data = {
#     "Baseline1": [[5, 5.1, 5.8], [5.5, 5.6, 6.1], [6, 6.2, 6.7], [6.1, 6.3, 6.8], [5.9, 6.0, 6.4]],  # Each inner list has [mean, median, 90p]
#     "Baseline2": [[6, 6.1, 6.8], [6.4, 6.5, 7], [6.7, 6.8, 7.3], [6.3, 6.4, 7], [6.1, 6.2, 6.9]],
#     "Baseline3": [[7, 7.1, 7.8], [7.2, 7.3, 8], [7.4, 7.5, 8.2], [7.1, 7.3, 8], [7.2, 7.4, 7.9]]
# }

# means = [np.mean([seed[0] for seed in baseline_data[baseline]]) for baseline in baseline_names]
# medians = [np.mean([seed[1] for seed in baseline_data[baseline]]) for baseline in baseline_names]
# p90s = [np.mean([seed[2] for seed in baseline_data[baseline]]) for baseline in baseline_names]

# # Create bars for means
# bars = plt.bar(baseline_names, means, color='lightblue', label='Mean')

# # Add median points on the bars
# for i, bar in enumerate(bars):
#     plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, medians[i] + 0.1, 'x', ha='center', va='bottom', color='black', fontsize=12, label='Median' if i==0 else "")

# # Add error bars to represent up to the 90p
# plt.errorbar(baseline_names, means, [0]*len(means), [p90 - mean for p90, mean in zip(p90s, means)], fmt='none', ecolor='red', capsize=5, label='90th Percentile')

# plt.ylabel('Value')
# plt.title('Metrics across different baselines')
# plt.legend()
# plt.show()

# %%
df[df['alg'] == "DBMS (instance-tuned)"]
# Out:
#                                  Tags                name       lr  \
# 0  [3a, final5-fixed_instances-min-1]  icy-waterfall-4116  0.00001
#
#                      alg  hl1        arch  seed  \
# 0  DBMS (instance-tuned)  512  factorized     1
#
#                                                 tags  \
# 0  exp10_single_zdbs,exp5_single_stats,exp8_singl...
#
#                                     config min_est  ...  \
# 0  configs/baselines/config_dbms_imdb.yaml    None  ...
#
#    Final-LatencyQError-train-median Final-LatencyMSE-train-90p  \
# 0                          9.928848                 737.231749
#
#    Final-LatencyMSE-test-median Final-LatencyQError-train-90p  \
# 0                    179.031049                     18.463977
#
#   Final-LatencyRelError-test-99p Final-LatencyRelError-train-median  \
# 0                      16.435893                           8.888694
#
#   Final-LatencyAE-train-90p  Final-LatencyMSE-train-mean  \
# 0                 27.152012                  4795.967726
#
#                       test_query_dir  workload
# 0  ./queries/ceb-small,./queries/job     Stack
#
# [1 rows x 121 columns]

# %%
set(df["alg"])
# Out:
# {'DBMS (instance-tuned)',
#  'GCN-Pretrained-0.0001extra-training-0wd-0.1-models4/noimdb_actual.wt',
#  'GCN-Pretrained-0.0001extra-training-0wd-0.1-models4/noimdb_noactual.wt',
#  'GCN-Pretrained-0.0001extra-training-1wd-0.1-models4/noimdb_actual.wt',
#  'GCN-Pretrained-1e-05extra-training-0wd-0.1-models4/tpch-ergast-stack_actual.wt',
#  'GCN-Pretrained-1e-05extra-training-1wd-0.1-models4/noimdb_noactual.wt',
#  'GCN-Pretrained-1e-05extra-training-1wd-0.1-models4/tpch-ergast-stack_actual.wt'}

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# FN_TMP = "{}-{}.pdf"

# # Define a function to check if the values have a large range and should be plotted in log scale
# def should_use_log_scale(values):
#     return max(values) / min(values) > 100  # Adjust this threshold if needed

# # Define a function to plot the given metrics
# def plot_metrics(data, metric_median, metric_90p, metric_mean, title):
#     fig, axs = plt.subplots(1, 3, figsize=(18,6))
#     plt.suptitle(title)
    
#     # Plot for Median values
#     sns.barplot(data=data, y=metric_median, x="num_instances", hue="alg", dodge=True, ax=axs[0], palette=HUES)
#     axs[0].set_title('Median')
#     if should_use_log_scale(data[metric_median]):
#         axs[0].set_yscale("log")

#     # Plot for 90th Percentile values
#     sns.barplot(data=data, y=metric_90p, x="num_instances", hue="alg", dodge=True, ax=axs[1], palette=HUES)
#     axs[1].set_title('90th Percentile')
#     if should_use_log_scale(data[metric_90p]):
#         axs[1].set_yscale("log")

#     # Plot for Mean values
#     sns.barplot(data=data, y=metric_mean, x="num_instances", hue="alg", dodge=True, ax=axs[2], palette=HUES)
#     axs[2].set_title('Mean')
    
#     if should_use_log_scale(data[metric_mean]):
#         axs[2].set_yscale("log")

#     # Remove individual legends and add a single legend at the top
#     for ax in axs:
#         ax.get_legend().remove()
#     handles, labels = axs[0].get_legend_handles_labels()
#     fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1.10), ncol=len(handles))

#     # Finalize the plot and save
#     plt.tight_layout()
#     fn = FN_TMP.format(wk, title.replace(' ', '-'))
#     print(fn)
#     plt.savefig(fn, bbox_inches="tight")

# # Loop through each unique workload
# for wk in set(df["workload"]):
#     tmp = df[df["workload"] == wk]
    
#     # Plot for MSE
#     plot_metrics(tmp, 
#                  'Final-LatencyMSE-test-median', 
#                  'Final-LatencyMSE-test-90p', 
#                  'Final-LatencyMSE-test-mean',
#                  'Latency MSE')

#     # Plot for Q-Error
#     plot_metrics(tmp, 
#                  'Final-LatencyQError-test-median', 
#                  'Final-LatencyQError-test-90p', 
#                  'Final-LatencyQError-test-mean',
#                  'Latency Q-Error')

    
#     # Plot for Q-Error
#     plot_metrics(tmp, 
#                  'Final-LatencyRelError-test-median', 
#                  'Final-LatencyRelError-test-90p', 
#                  'Final-LatencyRelError-test-mean',
#                  'Latency Relative Error')
    
#     # Plot for AE
#     plot_metrics(tmp, 
#                  'Final-LatencyAE-test-median', 
#                  'Final-LatencyAE-test-90p', 
#                  'Final-LatencyAE-test-mean',
#                  'Latency Absolute Error')

# %%
# FN_TMP = "{}-{}.pdf"
# for wk in set(df["workload"]):
#     tmp = df[df["workload"] == wk]
#     EB="ci"
#     TO_PLOT = ['Final-LatencyAE-test-median', 'Final-LatencyAE-test-mean']
#     fig,axs = plt.subplots(nrows=1, ncols=2, figsize=(12,6))

#     ## train
#     ax = axs[0]
#     sns.barplot(data=tmp, y=TO_PLOT[0], x="num_instances", hue="alg", dodge=True, 
#                 ax=ax, errorbar=EB, 
#                 palette=HUES)
#     legend = ax.legend(loc='upper left', bbox_to_anchor=(0.0,1.20), ncol=2, 
#                        frameon=False)

#     sns.barplot(data=tmp, y=TO_PLOT[1], x="num_instances", hue="alg", dodge=True, ax=axs[1], 
#                 errorbar=EB, palette=HUES)
#     axs[1].legend().remove()
    
#     fn = FN_TMP.format(wk, "MSE")
#     print(fn)
#     plt.savefig(fn, bbox_inches="tight")
    
#     TO_PLOT = ['Final-LatencyRelError-test-median', 'Final-LatencyRelError-test-90p']
#     fig,axs = plt.subplots(nrows=1, ncols=2, figsize=(12,6))
    
#     ## train
#     sns.barplot(data=tmp, y=TO_PLOT[0], x="num_instances", hue="alg", dodge=True, ax=axs[0], errorbar=EB,
#                palette=HUES)
#     #axs[0].legend().remove()
#     legend = axs[0].legend(loc='upper left', bbox_to_anchor=(0.0,1.20), ncol=2, 
#                frameon=False)
    
#     sns.barplot(data=tmp, y=TO_PLOT[1], x="num_instances", hue="alg", dodge=True, ax=axs[1], errorbar=EB,
#                palette=HUES)
#     axs[1].legend().remove()
    
#     fn = FN_TMP.format(wk, "Q-Error")
#     print(fn)
#     plt.savefig(fn, bbox_inches="tight")

# %%
# FN_TMP = "Test-{}-{}.pdf"
# for wk in set(df["workload"]):
#     tmp = df[df["workload"] == wk]
#     EB="sd"
#     TO_PLOT = ['Final-LatencyAE-train-mean', 'Final-LatencyAE-test-mean']
#     fig,axs = plt.subplots(nrows=1, ncols=1, figsize=(6,6))

#     ## train
# #     ax = axs[0]
# #     sns.barplot(data=tmp, y=TO_PLOT[0], x="num_instances", hue="alg", dodge=True, 
# #                 ax=ax, errorbar=EB, palette=HUES)
# #     legend = ax.legend(loc='upper left', bbox_to_anchor=(0.0,1.20), ncol=2, 
# #                        frameon=False)
    
#     ax = axs
#     sns.barplot(data=tmp, y=TO_PLOT[1], x="num_instances", hue="alg", dodge=True, ax=ax, 
#                 errorbar=EB, palette=HUES)
#     #axs[1].legend().remove()
#     ax.set_xlabel("Number of training instances", fontsize=20)
#     ax.set_ylabel("Latency AE", fontsize=20)
#     ax.tick_params(axis='both', which='major', labelsize=16)
    
#     fn = FN_TMP.format(wk, "MSE")
#     print(fn)
#     plt.savefig(fn, bbox_inches="tight")
    
#     TO_PLOT = ['Final-LatencyRelError-test-median', 'Final-LatencyRelError-test-90p']
#     fig,axs = plt.subplots(nrows=1, ncols=1, figsize=(6,6))
    
#     ## train
# #     sns.barplot(data=tmp, y=TO_PLOT[0], x="num_instances", hue="alg", dodge=True, ax=axs[0], errorbar=EB,
# #                palette=HUES)
#     #axs[0].legend().remove()
# #     legend = axs[0].legend(loc='upper left', bbox_to_anchor=(0.0,1.20), ncol=2, 
# #                frameon=False)
    
#     ax = axs
#     sns.barplot(data=tmp, y=TO_PLOT[1], x="num_instances", hue="alg", dodge=True, ax=axs, errorbar=EB,
#                palette=HUES)
    
#     ax.set_xlabel("Number of training instances", fontsize=20)
#     ax.set_ylabel("Latency Rel-Error", fontsize=20)
#     ax.tick_params(axis='both', which='major', labelsize=16)
#     #axs[1].legend().remove()
    
#     fn = FN_TMP.format(wk, "Q-Error")
#     print(fn)
#     plt.savefig(fn, bbox_inches="tight")
